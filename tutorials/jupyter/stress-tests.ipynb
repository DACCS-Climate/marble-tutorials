# %% [markdown]
# # Various stress tests to see if instance and services response adequately

# %% [markdown]
# ## Inputs and Configuration

# %%
# NBVAL_IGNORE_OUTPUT

import os
import random
import requests
import time
from datetime import datetime 
from inspect import cleandoc
from dataclasses import dataclass
import threading
from threading import Thread


PAVICS_HOST = os.getenv("PAVICS_HOST", "pavics.ouranos.ca").rstrip("/")
if not PAVICS_HOST:
    raise ValueError("Cannot run test without a PAVICS_HOST value.")

PAVICS_URL = f"https://{PAVICS_HOST}"
VERIFY_SSL = True if "DISABLE_VERIFY_SSL" not in os.environ else False
MAGPIE_URL = PAVICS_URL + "/magpie"
TWITCHER_PROXY = "/twitcher/ows/proxy"
TWITCHER_URL = PAVICS_URL + TWITCHER_PROXY
TWITCHER_URL = os.getenv("TWITCHER_URL") or TWITCHER_URL

# test config
TEST_WPS_BIRDS = str(os.getenv("TEST_WPS_BIRDS", "finch,flyingpigeon,raven,hummingbird"))
TEST_WPS_BIRDS = [bird.strip() for bird in TEST_WPS_BIRDS.split(",")]
if not len(TEST_WPS_BIRDS):
    raise ValueError("Cannot run test without at least one service in TEST_WPS_BIRDS.")

TEST_MAX_AVG_TIME = int(os.getenv("TEST_MAX_AVG_TIME", 1))     # maximum allowed request seconds on average for success
TEST_MAX_ERR_CODE = int(os.getenv("TEST_MAX_ERR_CODE", 0))     # maximum allowed amount of incorrect request status code
TEST_TIMEOUT_ABORT = int(os.getenv("TEST_TIMEOUT_ABORT", 5))   # maximum timeout duration to wait before abort request
TEST_TIMEOUT_RETRY = int(os.getenv("TEST_ABORT_THRESHOLD", 3)) # maximum request timeout retries before bird is aborted

TEST_RUNS_WPS = int(os.getenv("TEST_RUNS_WPS", 100))         # number of requests per tested bird
TEST_RUNS_THREDDS = int(os.getenv("TEST_RUNS_THREDDS", 500)) # number of requests for thredds test

TEST_N_THREADS_WPS = int(os.getenv("TEST_N_THREADS_WPS", 3))         # number of threads testing in parallel each bird
TEST_N_THREADS_THREDDS = int(os.getenv("TEST_N_THREADS_THREDDS", 5)) # number of threads testing in parallel thredds


print(f"PAVICS_HOST:    [{PAVICS_HOST}]")
print(f"TWITCHER_URL:   [{TWITCHER_URL}]")
print(f"TEST_WPS_BIRDS: {TEST_WPS_BIRDS}")
# Out:
# PAVICS_HOST:    [pavics.ouranos.ca]
# TWITCHER_URL:   [https://pavics.ouranos.ca/twitcher/ows/proxy]
# TEST_WPS_BIRDS: ['finch', 'flyingpigeon', 'raven', 'hummingbird']

# %% [markdown]
# ## Utilities

# %%
class StressTestProgression:
    """
    Class used by threads to keep track of the amount of request and progression of the tests. 
    Passed to each threads so that we know the progression in between threads
    """
    def __init__(self, n_threads: int, runs_per_threads: int):
        """
        :param n_threads: number of threads
        :param runs_per_threads: number of stress test request
        """
        self.count = 0
        self.n_threads = n_threads
        self.runs_per_threads = runs_per_threads
        self.total_runs = runs_per_threads * n_threads
        self.failed_threads_count: int = 0
        self.failed_requests_count: int = 0
        self.failed_stress_test_results = []

    def __str__(self):
        return str(self.__dict__)


    def increase(self, amount):
        self.count = self.count + amount

        if threading.current_thread().name:
            thread_name = threading.current_thread().name
            print(f"    {thread_name} --> Progress : {self.count}/{self.total_runs}   ")
        else:
            print(f"    Progress : {self.count}/{self.total_runs} ")

    def fail_report(self):
        report_error_message = "This test failed due to bad code received from the requests."
        report_error_message += f"\n Number of failed thread(s) : {self.failed_threads_count}/ {self.n_threads}"
        report_error_message += f"\n Number of failed requests : {self.failed_requests_count}/{self.total_runs}"
        
        for failed_result in self.failed_stress_test_results:
            i = 0
            for code in list(failed_result.codes):
                if code is failed_result.code:
                    del failed_result.codes[i:i+1]
                    del failed_result.delta[i:i+1]
                    del failed_result.times[i:i+1]
                    del failed_result.timestamps[i:i+1]
                    i -= 1
                i+= 1
                
            report_error_message += f"\n\n\n Failed Test"
            report_error_message += f"\n {failed_result}"
            
            report_error_message += f"\n\n === Exceptions ==="
            for i, exception in enumerate(failed_result.request_exceptions):
                code = failed_result.codes[i]
                if code == 408:
                    reason = "Request TimeOut (Client Side)"
                    exception_text = exception
                else :
                    reason = exception.response.reason
                    exception_text = exception.response.text
                    
                report_error_message += f"\n\n {i+1}. {code} {reason}"
                report_error_message += f"\n {exception_text}"
                
        return report_error_message


        
@dataclass
class StressTestResult:
    code: int = 200
    runs: int = 0
    max_avg_time: float = 0
    max_err_code: int = 0
    timeout_abort: int = 0
    timeout_retry: int = 0
    timeout_count: int = 0
    method: str = "GET"
    url: str = None
    request_args: dict = None
    status: int = 0  # see description of stress-test
    codes = []
    delta = []
    times = []
    timestamps = []
    request_exceptions = []

    @property
    def avg_time(self):
        return sum(self.times) / self.runs

    @property
    def min_time(self):
        return min(self.times)

    @property
    def max_time(self):
        return max(self.times)

    @property
    def sum_err_code(self):
        return sum([code != self.code for code in self.codes])

    def __str__(self):
        columns = ["Run", "Codes", "Delta", "Times", "Timestamps"]
        idx = len(str(self.runs))
        r = max(len(columns[0]), idx)
        w = 22
        header = "".join(f"{c:>{w if i else r}}" for i, c in enumerate(columns))
        offset = 16  # spaces offset of result lines, relative to this file
        data = [f"{i+1:>{r+(offset if i else 0)}}"
                f"{('(!) ' if c != self.code else '(x) ' if self.code == 408 else '') + str(c):>{w}}"
                f"{d:>{w-1}.3f}s"
                f"{t:>{w-1}.3f}s"
                f"{ts:>{w}}"
                for i, (c, d, t, ts)
                in enumerate(zip(self.codes, self.delta, self.times, self.timestamps))]
        lines = "\n".join(data)
        summary = "Undefined failure result status condition encountered."
        if self.status == 0:
            summary = [
                "All passing conditions have been achieved.",
            ]
        elif self.status == -1:
            summary = [
                f"Detected {self.sum_err_code} erroneous HTTP codes not equal to expected {self.code}."
            ]
        elif self.status == -2:
            summary = [
                f"Detected regression with long request time.",
                f"Expected max-avg-time: ({self.max_avg_time:.3f}s <= {self.max_time:.3f}s)."
            ]
        elif self.status == -3:
            summary = [
                f"Maximum number of timeout ({self.timeout_abort}s) requests exceeded ({self.timeout_count}).",
                "Test was aborted to avoid further delays."
            ]
        summary.append(f"Test {'succeeded' if self.status == 0 else 'failed'} (status={self.status}).")
        summary = ("\n" + offset * " ").join(summary)
        return cleandoc(f"""
        Stress Test:
            Test:
                code: {self.code}
                runs: {self.runs}
                max-avg-time:  {self.max_avg_time}s
                max-err-code:  {self.max_err_code}
                sum-err-code:  {self.sum_err_code}
                timeout-abort: {self.timeout_abort}s
                timeout-retry: {self.timeout_retry}
                timeout-count: {self.timeout_count}
            Request:
                method: {self.method}
                url:    {self.url}
                args:   {self.request_args}
            Times:
                min: {self.min_time:.3f}s
                avg: {self.avg_time:.3f}s
                max: {self.max_time:.3f}s
            Results:
                {header}
                {lines}
            Summary:
                {summary}
        """)


def stress_test_requests(stress_test_progression: StressTestProgression, url: str, method="GET", runs=100, code=200, delays=True,
                         max_err_code=0, max_avg_time=None,
                         abort_timeout=5, abort_retries=3, **req_kwargs) -> StressTestResult:
    """
    Executes the request for the number of demanded runs and validates the expected status is always returned.

    Outputs the results of each request and a summary of their execution time.
    If requested, also validates that all responses were returned on average faster than the maximum allowed time.

    :param stress_test_progression: StressTestProgress object to follow the progress of all requests
    :param url: endpoint to stress test
    :param method: HTTP method for request
    :param runs: number of stress test request
    :param code: expected HTTP code from requests
    :param delays: whether to apply small random delays between requests
       Otherwise, sequential requests are executed as quickly as possible, when the previous response is obtained.
    :param max_err_code: maximum amount of erroneous HTTP status code allowed to consider the test successful.
    :param max_avg_time: maximum average time of requests permitted to consider the test successful.
    :param abort_timeout: duration to wait until a request is aborted, sets 408 (Read Timeout) as HTTP status code.
    :param abort_retries: number of failed timeout requests allowed before abort of whole stress test for this endpoint.
    :returns:
        StressTestResult with individual request results and one of below status:
        -  0 (success) for no error and all conditions achieved
        - -1 (failure) for maximum amount of HTT error code reached
        - -2 (failure) for maximum request time on average reached
        - -3 (failure) for aborted test due to too many timeout
    """
    thread_name = threading.current_thread().name
    req_kwargs.pop("timeout", None)
    result = StressTestResult()
    result.runs = runs
    result.url = url
    result.method = method
    result.request_args = req_kwargs
    result.max_err_code = max_err_code
    result.max_avg_time = max_avg_time
    result.abort_timeout = abort_timeout
    result.abort_retries = abort_retries
    result.codes = []
    result.times = []
    result.timestamps = []
    result.request_exceptions = []
    result.delta = [0.] + [float((random.randint(1, 100) / 1000) if delays else 0) for _ in range(1, runs)]
    
    char = len(str(runs))
    for i in range(runs):
        start = time.perf_counter()
        try:
            resp = requests.request(method, url, timeout=abort_timeout, **req_kwargs)
            resp.raise_for_status()
        except requests.exceptions.RequestException as exe:
            code = 0
            if isinstance(exe, requests.exceptions.Timeout):
                code = 408 # read timeout
                result.times.append(abort_timeout)
                result.timeout_count += 1
            else:
                code = exe.response.status_code
            result.codes.append(code)
            result.request_exceptions.append(exe)
            stress_test_progression.failed_requests_count += 1
        else:
            result.codes.append(resp.status_code)
            result.times.append(time.perf_counter() - start)
            result.timestamps.append(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        if result.timeout_count > abort_timeout:
            result.status = -3
            print(f"Aborted: Too Many Timeout ({result.timeout_count})")
            return result
        if i == runs:
            break
        if result.delta[i]:
            time.sleep(result.delta[i])
        progress_update = 50
        if i!=0 and not (i-1)%progress_update:
            stress_test_progression.increase(progress_update)
    if max_avg_time and result.avg_time > max_avg_time:
        result.status = -2
    elif len([c for c in result.codes if c == code]) >= (runs - max_err_code):
        result.status = 0
    else:
        result.status = -1
    return result

# %%
def run_threads(target_test, url, execution_id:int = 1, n_threads:int = 1, runs_per_threads:int = 100):
    """
    This function launch n new thread with the target function to be executed.
    
    :param target_test: Function to be executed by the threads
    :param url: url to be called by the test
    :param execution_id: execution id to keep track of multiple execution, if this function is ran in a loop 
    :param n_threads: number of threads to be launched 
    :param runs_per_threads: number of stress test request per threads
    """

    stress_test_progression = StressTestProgression(n_threads, runs_per_threads)

    line = "-"*104
    print(line)
    print(f"URL Execution-{execution_id}")
    print(f'- Starting {n_threads} threads with {runs_per_threads} runs per threads targeting "{target_test.__name__}" function.')
    print(f"- URL : {url}")
    print(f"- Initial progression values : {stress_test_progression}")
    print(line)

    threads = [
        Thread(
            target=target_test,
            args=(url, stress_test_progression),
            name=f"Thread-{i+1}",
        )
        for i in range(n_threads)
    ]

    for thread in threads:
        thread.start()

    for thread in threads:
        thread.join()

    assert (
        stress_test_progression.failed_threads_count == 0
    ), stress_test_progression.fail_report()
    
    print(f"All threads passed {target_test.__name__} function.")


def stress_test(url: str, stress_test_progression: StressTestProgression):
    """
    This function launch N new thread with the target function to be executed.

    :param url: url to be requested
    :param stress_test_progression: StressTestProgression object to follow the progress of all requests
    """

    failed_count = 0
    failed_results = ""

    n_runs = stress_test_progression.runs_per_threads

    expect_status_code = 200
    results = stress_test_requests(stress_test_progression, url, runs=n_runs, code=expect_status_code,
                                   max_err_code=TEST_MAX_ERR_CODE, max_avg_time=TEST_MAX_AVG_TIME,
                                   abort_retries=TEST_TIMEOUT_RETRY, abort_timeout=TEST_TIMEOUT_ABORT)

    thread_name = threading.current_thread().name
    print(f"\n({thread_name}) Stress Test with [{n_runs}] calls \n to : [{url}]")
    print(results)

    if results.status != 0:
        failed_count += 1
        stress_test_progression.failed_threads_count += 1
        stress_test_progression.failed_stress_test_results.append(results)
        failed_results = f"{failed_results}\n{results}"

    assert failed_count == 0, f"Failed {failed_count} tests.  Failed results: {failed_results}"
    print(f"\n{thread_name} : All tests passed!")

# %% [markdown]
# ## Tests

# %%
# NBVAL_IGNORE_OUTPUT

# Executing WPS test on multiple threads
wps_urls = [
    f"{TWITCHER_URL}/{bird}/wps?service=wps&request=getcapabilities"
    for bird in TEST_WPS_BIRDS
]

for execution, url in enumerate(wps_urls):
    run_threads(target_test = stress_test,
                url = url,
                execution_id = execution,
                n_threads = TEST_N_THREADS_WPS,
                runs_per_threads = TEST_RUNS_WPS)
# Out:
# --------------------------------------------------------------------------------------------------------
# URL Execution-0
# - Starting 3 threads with 100 runs per threads targeting "stress_test" function.
# - URL : https://pavics.ouranos.ca/twitcher/ows/proxy/finch/wps?service=wps&request=getcapabilities
# - Initial progression values : {'count': 0, 'n_threads': 3, 'runs_per_threads': 100, 'total_runs': 300, 'failed_threads_count': 0, 'failed_requests_count': 0, 'failed_stress_test_results': []}
# --------------------------------------------------------------------------------------------------------
#     Thread-1 --> Progress : 50/300
#     Thread-2 --> Progress : 100/300
#     Thread-3 --> Progress : 150/300
#     Thread-1 --> Progress : 200/300
#     Thread-2 --> Progress : 250/300
#     Thread-3 --> Progress : 300/300
#
# (Thread-1) Stress Test with [100] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/finch/wps?service=wps&request=getcapabilities]
# Stress Test:
#     Test:
#         code: 200
#         runs: 100
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/finch/wps?service=wps&request=getcapabilities
#         args:   {}
#     Times:
#         min: 0.272s
#         avg: 0.474s
#         max: 0.761s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.283s   2021-11-23 20:23:57
#           2                   200                0.052s                0.607s   2021-11-23 20:23:58
#           3                   200                0.065s                0.359s   2021-11-23 20:23:58
#           4                   200                0.023s                0.609s   2021-11-23 20:23:59
#           5                   200                0.032s                0.424s   2021-11-23 20:23:59
#           6                   200                0.061s                0.549s   2021-11-23 20:24:00
#           7                   200                0.082s                0.338s   2021-11-23 20:24:00
#           8                   200                0.067s                0.453s   2021-11-23 20:24:01
#           9                   200                0.037s                0.675s   2021-11-23 20:24:01
#          10                   200                0.042s                0.732s   2021-11-23 20:24:02
#          11                   200                0.033s                0.579s   2021-11-23 20:24:03
#          12                   200                0.087s                0.582s   2021-11-23 20:24:03
#          13                   200                0.061s                0.276s   2021-11-23 20:24:04
#          14                   200                0.046s                0.605s   2021-11-23 20:24:04
#          15                   200                0.080s                0.514s   2021-11-23 20:24:05
#          16                   200                0.057s                0.761s   2021-11-23 20:24:06
#          17                   200                0.069s                0.370s   2021-11-23 20:24:06
#          18                   200                0.061s                0.535s   2021-11-23 20:24:07
#          19                   200                0.011s                0.619s   2021-11-23 20:24:08
#          20                   200                0.077s                0.369s   2021-11-23 20:24:08
#          21                   200                0.031s                0.557s   2021-11-23 20:24:09
#          22                   200                0.042s                0.336s   2021-11-23 20:24:09
#          23                   200                0.074s                0.570s   2021-11-23 20:24:10
#          24                   200                0.052s                0.506s   2021-11-23 20:24:10
#          25                   200                0.095s                0.286s   2021-11-23 20:24:10
#          26                   200                0.006s                0.458s   2021-11-23 20:24:11
#          27                   200                0.063s                0.403s   2021-11-23 20:24:11
#          28                   200                0.076s                0.606s   2021-11-23 20:24:12
#          29                   200                0.006s                0.615s   2021-11-23 20:24:13
#          30                   200                0.092s                0.384s   2021-11-23 20:24:13
#          31                   200                0.051s                0.498s   2021-11-23 20:24:14
#          32                   200                0.007s                0.315s   2021-11-23 20:24:14
#          33                   200                0.014s                0.601s   2021-11-23 20:24:15
#          34                   200                0.084s                0.661s   2021-11-23 20:24:15
#          35                   200                0.086s                0.314s   2021-11-23 20:24:16
#          36                   200                0.090s                0.572s   2021-11-23 20:24:16
#          37                   200                0.028s                0.322s   2021-11-23 20:24:17
#          38                   200                0.050s                0.541s   2021-11-23 20:24:17
#          39                   200                0.080s                0.491s   2021-11-23 20:24:18
#          40                   200                0.065s                0.351s   2021-11-23 20:24:18
#          41                   200                0.040s                0.631s   2021-11-23 20:24:19
#          42                   200                0.070s                0.369s   2021-11-23 20:24:20
#          43                   200                0.022s                0.556s   2021-11-23 20:24:20
#          44                   200                0.062s                0.602s   2021-11-23 20:24:21
#          45                   200                0.024s                0.387s   2021-11-23 20:24:21
#          46                   200                0.008s                0.538s   2021-11-23 20:24:22
#          47                   200                0.074s                0.403s   2021-11-23 20:24:22
#          48                   200                0.080s                0.501s   2021-11-23 20:24:23
#          49                   200                0.030s                0.464s   2021-11-23 20:24:23
#          50                   200                0.070s                0.333s   2021-11-23 20:24:24
#          51                   200                0.084s                0.476s   2021-11-23 20:24:24
#          52                   200                0.044s                0.272s   2021-11-23 20:24:25
#          53                   200                0.065s                0.617s   2021-11-23 20:24:25
#          54                   200                0.058s                0.683s   2021-11-23 20:24:26
#          55                   200                0.071s                0.346s   2021-11-23 20:24:26
#          56                   200                0.059s                0.489s   2021-11-23 20:24:27
#          57                   200                0.029s                0.469s   2021-11-23 20:24:27
#          58                   200                0.020s                0.401s   2021-11-23 20:24:28
#          59                   200                0.014s                0.592s   2021-11-23 20:24:29
#          60                   200                0.087s                0.357s   2021-11-23 20:24:29
#          61                   200                0.049s                0.454s   2021-11-23 20:24:29
#          62                   200                0.077s                0.354s   2021-11-23 20:24:30
#          63                   200                0.097s                0.499s   2021-11-23 20:24:30
#          64                   200                0.059s                0.580s   2021-11-23 20:24:31
#          65                   200                0.019s                0.335s   2021-11-23 20:24:31
#          66                   200                0.050s                0.610s   2021-11-23 20:24:32
#          67                   200                0.015s                0.532s   2021-11-23 20:24:33
#          68                   200                0.090s                0.418s   2021-11-23 20:24:33
#          69                   200                0.018s                0.487s   2021-11-23 20:24:34
#          70                   200                0.095s                0.367s   2021-11-23 20:24:34
#          71                   200                0.093s                0.462s   2021-11-23 20:24:35
#          72                   200                0.007s                0.310s   2021-11-23 20:24:35
#          73                   200                0.037s                0.538s   2021-11-23 20:24:36
#          74                   200                0.005s                0.520s   2021-11-23 20:24:36
#          75                   200                0.014s                0.392s   2021-11-23 20:24:37
#          76                   200                0.068s                0.503s   2021-11-23 20:24:37
#          77                   200                0.079s                0.520s   2021-11-23 20:24:38
#          78                   200                0.023s                0.304s   2021-11-23 20:24:38
#          79                   200                0.009s                0.504s   2021-11-23 20:24:39
#          80                   200                0.010s                0.357s   2021-11-23 20:24:39
#          81                   200                0.009s                0.537s   2021-11-23 20:24:39
#          82                   200                0.030s                0.433s   2021-11-23 20:24:40
#          83                   200                0.008s                0.508s   2021-11-23 20:24:40
#          84                   200                0.013s                0.585s   2021-11-23 20:24:41
#          85                   200                0.045s                0.396s   2021-11-23 20:24:41
#          86                   200                0.069s                0.598s   2021-11-23 20:24:42
#          87                   200                0.095s                0.521s   2021-11-23 20:24:43
#          88                   200                0.075s                0.314s   2021-11-23 20:24:43
#          89                   200                0.057s                0.491s   2021-11-23 20:24:44
#          90                   200                0.026s                0.336s   2021-11-23 20:24:44
#          91                   200                0.070s                0.572s   2021-11-23 20:24:45
#          92                   200                0.089s                0.317s   2021-11-23 20:24:45
#          93                   200                0.081s                0.532s   2021-11-23 20:24:46
#          94                   200                0.072s                0.501s   2021-11-23 20:24:46
#          95                   200                0.001s                0.341s   2021-11-23 20:24:47
#          96                   200                0.048s                0.506s   2021-11-23 20:24:47
#          97                   200                0.078s                0.502s   2021-11-23 20:24:48
#          98                   200                0.020s                0.357s   2021-11-23 20:24:48
#          99                   200                0.067s                0.574s   2021-11-23 20:24:49
#         100                   200                0.058s                0.353s   2021-11-23 20:24:49
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-1 : All tests passed!
# (Thread-2) Stress Test with [100] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/finch/wps?service=wps&request=getcapabilities]
# Stress Test:
#     Test:
#         code: 200
#         runs: 100
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/finch/wps?service=wps&request=getcapabilities
#         args:   {}
#     Times:
#         min: 0.252s
#         avg: 0.479s
#         max: 0.737s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.429s   2021-11-23 20:23:57
#           2                   200                0.053s                0.606s   2021-11-23 20:23:58
#           3                   200                0.035s                0.375s   2021-11-23 20:23:58
#           4                   200                0.095s                0.602s   2021-11-23 20:23:59
#           5                   200                0.022s                0.525s   2021-11-23 20:23:59
#           6                   200                0.034s                0.412s   2021-11-23 20:24:00
#           7                   200                0.031s                0.514s   2021-11-23 20:24:00
#           8                   200                0.065s                0.334s   2021-11-23 20:24:01
#           9                   200                0.059s                0.698s   2021-11-23 20:24:02
#          10                   200                0.044s                0.705s   2021-11-23 20:24:02
#          11                   200                0.004s                0.720s   2021-11-23 20:24:03
#          12                   200                0.092s                0.414s   2021-11-23 20:24:03
#          13                   200                0.055s                0.547s   2021-11-23 20:24:04
#          14                   200                0.090s                0.345s   2021-11-23 20:24:05
#          15                   200                0.055s                0.627s   2021-11-23 20:24:05
#          16                   200                0.011s                0.669s   2021-11-23 20:24:06
#          17                   200                0.020s                0.622s   2021-11-23 20:24:07
#          18                   200                0.023s                0.389s   2021-11-23 20:24:07
#          19                   200                0.039s                0.631s   2021-11-23 20:24:08
#          20                   200                0.095s                0.332s   2021-11-23 20:24:08
#          21                   200                0.064s                0.561s   2021-11-23 20:24:09
#          22                   200                0.024s                0.308s   2021-11-23 20:24:09
#          23                   200                0.003s                0.538s   2021-11-23 20:24:10
#          24                   200                0.086s                0.606s   2021-11-23 20:24:10
#          25                   200                0.023s                0.252s   2021-11-23 20:24:11
#          26                   200                0.016s                0.518s   2021-11-23 20:24:11
#          27                   200                0.090s                0.623s   2021-11-23 20:24:12
#          28                   200                0.088s                0.390s   2021-11-23 20:24:12
#          29                   200                0.051s                0.569s   2021-11-23 20:24:13
#          30                   200                0.056s                0.348s   2021-11-23 20:24:13
#          31                   200                0.036s                0.542s   2021-11-23 20:24:14
#          32                   200                0.078s                0.321s   2021-11-23 20:24:14
#          33                   200                0.053s                0.556s   2021-11-23 20:24:15
#          34                   200                0.026s                0.614s   2021-11-23 20:24:16
#          35                   200                0.077s                0.395s   2021-11-23 20:24:16
#          36                   200                0.044s                0.540s   2021-11-23 20:24:17
#          37                   200                0.066s                0.515s   2021-11-23 20:24:17
#          38                   200                0.004s                0.364s   2021-11-23 20:24:18
#          39                   200                0.081s                0.569s   2021-11-23 20:24:18
#          40                   200                0.067s                0.331s   2021-11-23 20:24:19
#          41                   200                0.080s                0.618s   2021-11-23 20:24:19
#          42                   200                0.020s                0.342s   2021-11-23 20:24:20
#          43                   200                0.038s                0.591s   2021-11-23 20:24:20
#          44                   200                0.025s                0.602s   2021-11-23 20:24:21
#          45                   200                0.045s                0.414s   2021-11-23 20:24:21
#          46                   200                0.055s                0.532s   2021-11-23 20:24:22
#          47                   200                0.047s                0.499s   2021-11-23 20:24:22
#          48                   200                0.040s                0.387s   2021-11-23 20:24:23
#          49                   200                0.079s                0.461s   2021-11-23 20:24:23
#          50                   200                0.098s                0.325s   2021-11-23 20:24:24
#          51                   200                0.085s                0.411s   2021-11-23 20:24:24
#          52                   200                0.018s                0.292s   2021-11-23 20:24:25
#          53                   200                0.046s                0.614s   2021-11-23 20:24:25
#          54                   200                0.085s                0.737s   2021-11-23 20:24:26
#          55                   200                0.082s                0.333s   2021-11-23 20:24:27
#          56                   200                0.062s                0.423s   2021-11-23 20:24:27
#          57                   200                0.014s                0.504s   2021-11-23 20:24:28
#          58                   200                0.021s                0.391s   2021-11-23 20:24:28
#          59                   200                0.034s                0.589s   2021-11-23 20:24:29
#          60                   200                0.012s                0.536s   2021-11-23 20:24:29
#          61                   200                0.096s                0.362s   2021-11-23 20:24:30
#          62                   200                0.082s                0.444s   2021-11-23 20:24:30
#          63                   200                0.073s                0.400s   2021-11-23 20:24:31
#          64                   200                0.025s                0.553s   2021-11-23 20:24:31
#          65                   200                0.078s                0.364s   2021-11-23 20:24:32
#          66                   200                0.071s                0.569s   2021-11-23 20:24:32
#          67                   200                0.023s                0.519s   2021-11-23 20:24:33
#          68                   200                0.092s                0.422s   2021-11-23 20:24:33
#          69                   200                0.089s                0.437s   2021-11-23 20:24:34
#          70                   200                0.080s                0.487s   2021-11-23 20:24:34
#          71                   200                0.037s                0.338s   2021-11-23 20:24:35
#          72                   200                0.052s                0.468s   2021-11-23 20:24:35
#          73                   200                0.004s                0.342s   2021-11-23 20:24:36
#          74                   200                0.080s                0.553s   2021-11-23 20:24:36
#          75                   200                0.019s                0.319s   2021-11-23 20:24:37
#          76                   200                0.017s                0.504s   2021-11-23 20:24:37
#          77                   200                0.045s                0.606s   2021-11-23 20:24:38
#          78                   200                0.015s                0.276s   2021-11-23 20:24:38
#          79                   200                0.086s                0.516s   2021-11-23 20:24:39
#          80                   200                0.021s                0.492s   2021-11-23 20:24:39
#          81                   200                0.025s                0.356s   2021-11-23 20:24:40
#          82                   200                0.036s                0.556s   2021-11-23 20:24:40
#          83                   200                0.019s                0.343s   2021-11-23 20:24:41
#          84                   200                0.031s                0.565s   2021-11-23 20:24:41
#          85                   200                0.037s                0.387s   2021-11-23 20:24:42
#          86                   200                0.015s                0.634s   2021-11-23 20:24:42
#          87                   200                0.014s                0.547s   2021-11-23 20:24:43
#          88                   200                0.097s                0.410s   2021-11-23 20:24:43
#          89                   200                0.088s                0.451s   2021-11-23 20:24:44
#          90                   200                0.077s                0.487s   2021-11-23 20:24:44
#          91                   200                0.005s                0.357s   2021-11-23 20:24:45
#          92                   200                0.004s                0.547s   2021-11-23 20:24:45
#          93                   200                0.020s                0.416s   2021-11-23 20:24:46
#          94                   200                0.089s                0.601s   2021-11-23 20:24:46
#          95                   200                0.098s                0.299s   2021-11-23 20:24:47
#          96                   200                0.025s                0.412s   2021-11-23 20:24:47
#          97                   200                0.034s                0.552s   2021-11-23 20:24:48
#          98                   200                0.048s                0.375s   2021-11-23 20:24:48
#          99                   200                0.063s                0.585s   2021-11-23 20:24:49
#         100                   200                0.057s                0.455s   2021-11-23 20:24:49
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-2 : All tests passed!
#
# (Thread-3) Stress Test with [100] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/finch/wps?service=wps&request=getcapabilities]
# Stress Test:
#     Test:
#         code: 200
#         runs: 100
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/finch/wps?service=wps&request=getcapabilities
#         args:   {}
#     Times:
#         min: 0.241s
#         avg: 0.481s
#         max: 0.713s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.567s   2021-11-23 20:23:57
#           2                   200                0.078s                0.580s   2021-11-23 20:23:58
#           3                   200                0.057s                0.369s   2021-11-23 20:23:58
#           4                   200                0.081s                0.598s   2021-11-23 20:23:59
#           5                   200                0.039s                0.537s   2021-11-23 20:24:00
#           6                   200                0.089s                0.376s   2021-11-23 20:24:00
#           7                   200                0.010s                0.442s   2021-11-23 20:24:01
#           8                   200                0.020s                0.554s   2021-11-23 20:24:01
#           9                   200                0.071s                0.691s   2021-11-23 20:24:02
#          10                   200                0.087s                0.713s   2021-11-23 20:24:03
#          11                   200                0.098s                0.534s   2021-11-23 20:24:03
#          12                   200                0.041s                0.309s   2021-11-23 20:24:04
#          13                   200                0.067s                0.616s   2021-11-23 20:24:04
#          14                   200                0.061s                0.481s   2021-11-23 20:24:05
#          15                   200                0.056s                0.510s   2021-11-23 20:24:05
#          16                   200                0.029s                0.668s   2021-11-23 20:24:06
#          17                   200                0.089s                0.572s   2021-11-23 20:24:07
#          18                   200                0.005s                0.359s   2021-11-23 20:24:07
#          19                   200                0.013s                0.613s   2021-11-23 20:24:08
#          20                   200                0.055s                0.607s   2021-11-23 20:24:08
#          21                   200                0.021s                0.339s   2021-11-23 20:24:09
#          22                   200                0.041s                0.574s   2021-11-23 20:24:09
#          23                   200                0.090s                0.306s   2021-11-23 20:24:10
#          24                   200                0.008s                0.497s   2021-11-23 20:24:10
#          25                   200                0.018s                0.354s   2021-11-23 20:24:11
#          26                   200                0.013s                0.554s   2021-11-23 20:24:11
#          27                   200                0.097s                0.660s   2021-11-23 20:24:12
#          28                   200                0.077s                0.335s   2021-11-23 20:24:12
#          29                   200                0.050s                0.582s   2021-11-23 20:24:13
#          30                   200                0.061s                0.551s   2021-11-23 20:24:14
#          31                   200                0.002s                0.319s   2021-11-23 20:24:14
#          32                   200                0.013s                0.570s   2021-11-23 20:24:15
#          33                   200                0.048s                0.435s   2021-11-23 20:24:15
#          34                   200                0.082s                0.594s   2021-11-23 20:24:16
#          35                   200                0.043s                0.381s   2021-11-23 20:24:16
#          36                   200                0.078s                0.545s   2021-11-23 20:24:17
#          37                   200                0.017s                0.498s   2021-11-23 20:24:17
#          38                   200                0.046s                0.369s   2021-11-23 20:24:18
#          39                   200                0.038s                0.537s   2021-11-23 20:24:18
#          40                   200                0.005s                0.632s   2021-11-23 20:24:19
#          41                   200                0.018s                0.437s   2021-11-23 20:24:19
#          42                   200                0.015s                0.628s   2021-11-23 20:24:20
#          43                   200                0.073s                0.364s   2021-11-23 20:24:20
#          44                   200                0.015s                0.570s   2021-11-23 20:24:21
#          45                   200                0.026s                0.435s   2021-11-23 20:24:21
#          46                   200                0.019s                0.554s   2021-11-23 20:24:22
#          47                   200                0.078s                0.536s   2021-11-23 20:24:23
#          48                   200                0.030s                0.313s   2021-11-23 20:24:23
#          49                   200                0.017s                0.477s   2021-11-23 20:24:24
#          50                   200                0.096s                0.555s   2021-11-23 20:24:24
#          51                   200                0.029s                0.241s   2021-11-23 20:24:24
#          52                   200                0.068s                0.614s   2021-11-23 20:24:25
#          53                   200                0.022s                0.704s   2021-11-23 20:24:26
#          54                   200                0.042s                0.381s   2021-11-23 20:24:26
#          55                   200                0.032s                0.526s   2021-11-23 20:24:27
#          56                   200                0.080s                0.300s   2021-11-23 20:24:27
#          57                   200                0.078s                0.525s   2021-11-23 20:24:28
#          58                   200                0.067s                0.520s   2021-11-23 20:24:28
#          59                   200                0.089s                0.351s   2021-11-23 20:24:29
#          60                   200                0.075s                0.448s   2021-11-23 20:24:29
#          61                   200                0.013s                0.299s   2021-11-23 20:24:30
#          62                   200                0.059s                0.551s   2021-11-23 20:24:30
#          63                   200                0.070s                0.614s   2021-11-23 20:24:31
#          64                   200                0.086s                0.342s   2021-11-23 20:24:31
#          65                   200                0.023s                0.535s   2021-11-23 20:24:32
#          66                   200                0.033s                0.415s   2021-11-23 20:24:32
#          67                   200                0.090s                0.551s   2021-11-23 20:24:33
#          68                   200                0.021s                0.506s   2021-11-23 20:24:34
#          69                   200                0.002s                0.378s   2021-11-23 20:24:34
#          70                   200                0.021s                0.528s   2021-11-23 20:24:34
#          71                   200                0.073s                0.376s   2021-11-23 20:24:35
#          72                   200                0.029s                0.483s   2021-11-23 20:24:35
#          73                   200                0.081s                0.502s   2021-11-23 20:24:36
#          74                   200                0.087s                0.345s   2021-11-23 20:24:36
#          75                   200                0.071s                0.448s   2021-11-23 20:24:37
#          76                   200                0.074s                0.300s   2021-11-23 20:24:37
#          77                   200                0.024s                0.527s   2021-11-23 20:24:38
#          78                   200                0.050s                0.480s   2021-11-23 20:24:38
#          79                   200                0.068s                0.348s   2021-11-23 20:24:39
#          80                   200                0.003s                0.465s   2021-11-23 20:24:39
#          81                   200                0.016s                0.393s   2021-11-23 20:24:40
#          82                   200                0.093s                0.562s   2021-11-23 20:24:40
#          83                   200                0.053s                0.475s   2021-11-23 20:24:41
#          84                   200                0.028s                0.361s   2021-11-23 20:24:41
#          85                   200                0.001s                0.620s   2021-11-23 20:24:42
#          86                   200                0.087s                0.416s   2021-11-23 20:24:42
#          87                   200                0.029s                0.508s   2021-11-23 20:24:43
#          88                   200                0.026s                0.519s   2021-11-23 20:24:44
#          89                   200                0.010s                0.364s   2021-11-23 20:24:44
#          90                   200                0.013s                0.609s   2021-11-23 20:24:45
#          91                   200                0.088s                0.356s   2021-11-23 20:24:45
#          92                   200                0.078s                0.504s   2021-11-23 20:24:45
#          93                   200                0.085s                0.486s   2021-11-23 20:24:46
#          94                   200                0.059s                0.371s   2021-11-23 20:24:47
#          95                   200                0.074s                0.478s   2021-11-23 20:24:47
#          96                   200                0.054s                0.295s   2021-11-23 20:24:47
#          97                   200                0.087s                0.528s   2021-11-23 20:24:48
#          98                   200                0.047s                0.517s   2021-11-23 20:24:49
#          99                   200                0.018s                0.361s   2021-11-23 20:24:49
#         100                   200                0.019s                0.527s   2021-11-23 20:24:50
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-3 : All tests passed!
# All threads passed stress_test function.
# --------------------------------------------------------------------------------------------------------
# URL Execution-1
# - Starting 3 threads with 100 runs per threads targeting "stress_test" function.
# - URL : https://pavics.ouranos.ca/twitcher/ows/proxy/flyingpigeon/wps?service=wps&request=getcapabilities
# - Initial progression values : {'count': 0, 'n_threads': 3, 'runs_per_threads': 100, 'total_runs': 300, 'failed_threads_count': 0, 'failed_requests_count': 0, 'failed_stress_test_results': []}
# --------------------------------------------------------------------------------------------------------
#     Thread-3 --> Progress : 50/300
#     Thread-1 --> Progress : 100/300
#     Thread-2 --> Progress : 150/300
#     Thread-3 --> Progress : 200/300
#     Thread-1 --> Progress : 250/300
#     Thread-2 --> Progress : 300/300
#
# (Thread-1) Stress Test with [100] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/flyingpigeon/wps?service=wps&request=getcapabilities]
# Stress Test:
#     Test:
#         code: 200
#         runs: 100
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/flyingpigeon/wps?service=wps&request=getcapabilities
#         args:   {}
#     Times:
#         min: 0.133s
#         avg: 0.193s
#         max: 0.291s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.282s   2021-11-23 20:24:50
#           2                   200                0.035s                0.249s   2021-11-23 20:24:50
#           3                   200                0.083s                0.186s   2021-11-23 20:24:50
#           4                   200                0.011s                0.176s   2021-11-23 20:24:51
#           5                   200                0.090s                0.176s   2021-11-23 20:24:51
#           6                   200                0.096s                0.155s   2021-11-23 20:24:51
#           7                   200                0.019s                0.165s   2021-11-23 20:24:51
#           8                   200                0.067s                0.209s   2021-11-23 20:24:52
#           9                   200                0.055s                0.167s   2021-11-23 20:24:52
#          10                   200                0.015s                0.244s   2021-11-23 20:24:52
#          11                   200                0.018s                0.290s   2021-11-23 20:24:52
#          12                   200                0.043s                0.165s   2021-11-23 20:24:53
#          13                   200                0.037s                0.165s   2021-11-23 20:24:53
#          14                   200                0.083s                0.188s   2021-11-23 20:24:53
#          15                   200                0.086s                0.164s   2021-11-23 20:24:53
#          16                   200                0.032s                0.239s   2021-11-23 20:24:54
#          17                   200                0.046s                0.158s   2021-11-23 20:24:54
#          18                   200                0.051s                0.169s   2021-11-23 20:24:54
#          19                   200                0.084s                0.165s   2021-11-23 20:24:54
#          20                   200                0.028s                0.162s   2021-11-23 20:24:54
#          21                   200                0.072s                0.167s   2021-11-23 20:24:55
#          22                   200                0.080s                0.168s   2021-11-23 20:24:55
#          23                   200                0.014s                0.140s   2021-11-23 20:24:55
#          24                   200                0.054s                0.164s   2021-11-23 20:24:55
#          25                   200                0.080s                0.183s   2021-11-23 20:24:55
#          26                   200                0.098s                0.193s   2021-11-23 20:24:56
#          27                   200                0.015s                0.241s   2021-11-23 20:24:56
#          28                   200                0.085s                0.174s   2021-11-23 20:24:56
#          29                   200                0.062s                0.207s   2021-11-23 20:24:57
#          30                   200                0.039s                0.175s   2021-11-23 20:24:57
#          31                   200                0.046s                0.232s   2021-11-23 20:24:57
#          32                   200                0.087s                0.177s   2021-11-23 20:24:57
#          33                   200                0.078s                0.265s   2021-11-23 20:24:58
#          34                   200                0.091s                0.234s   2021-11-23 20:24:58
#          35                   200                0.097s                0.149s   2021-11-23 20:24:58
#          36                   200                0.023s                0.172s   2021-11-23 20:24:58
#          37                   200                0.100s                0.186s   2021-11-23 20:24:59
#          38                   200                0.078s                0.255s   2021-11-23 20:24:59
#          39                   200                0.098s                0.267s   2021-11-23 20:24:59
#          40                   200                0.053s                0.189s   2021-11-23 20:25:00
#          41                   200                0.024s                0.219s   2021-11-23 20:25:00
#          42                   200                0.074s                0.257s   2021-11-23 20:25:00
#          43                   200                0.041s                0.273s   2021-11-23 20:25:01
#          44                   200                0.087s                0.227s   2021-11-23 20:25:01
#          45                   200                0.069s                0.173s   2021-11-23 20:25:01
#          46                   200                0.007s                0.195s   2021-11-23 20:25:01
#          47                   200                0.056s                0.178s   2021-11-23 20:25:02
#          48                   200                0.088s                0.221s   2021-11-23 20:25:02
#          49                   200                0.071s                0.213s   2021-11-23 20:25:02
#          50                   200                0.029s                0.189s   2021-11-23 20:25:02
#          51                   200                0.007s                0.227s   2021-11-23 20:25:03
#          52                   200                0.066s                0.183s   2021-11-23 20:25:03
#          53                   200                0.035s                0.147s   2021-11-23 20:25:03
#          54                   200                0.077s                0.173s   2021-11-23 20:25:03
#          55                   200                0.085s                0.160s   2021-11-23 20:25:04
#          56                   200                0.022s                0.163s   2021-11-23 20:25:04
#          57                   200                0.003s                0.133s   2021-11-23 20:25:04
#          58                   200                0.073s                0.151s   2021-11-23 20:25:04
#          59                   200                0.055s                0.200s   2021-11-23 20:25:04
#          60                   200                0.066s                0.190s   2021-11-23 20:25:05
#          61                   200                0.036s                0.190s   2021-11-23 20:25:05
#          62                   200                0.030s                0.158s   2021-11-23 20:25:05
#          63                   200                0.006s                0.166s   2021-11-23 20:25:05
#          64                   200                0.043s                0.194s   2021-11-23 20:25:05
#          65                   200                0.031s                0.175s   2021-11-23 20:25:06
#          66                   200                0.072s                0.204s   2021-11-23 20:25:06
#          67                   200                0.076s                0.186s   2021-11-23 20:25:06
#          68                   200                0.070s                0.162s   2021-11-23 20:25:06
#          69                   200                0.086s                0.192s   2021-11-23 20:25:07
#          70                   200                0.048s                0.177s   2021-11-23 20:25:07
#          71                   200                0.003s                0.162s   2021-11-23 20:25:07
#          72                   200                0.046s                0.195s   2021-11-23 20:25:07
#          73                   200                0.083s                0.184s   2021-11-23 20:25:08
#          74                   200                0.039s                0.174s   2021-11-23 20:25:08
#          75                   200                0.080s                0.153s   2021-11-23 20:25:08
#          76                   200                0.097s                0.163s   2021-11-23 20:25:08
#          77                   200                0.059s                0.204s   2021-11-23 20:25:09
#          78                   200                0.022s                0.145s   2021-11-23 20:25:09
#          79                   200                0.080s                0.166s   2021-11-23 20:25:09
#          80                   200                0.004s                0.163s   2021-11-23 20:25:09
#          81                   200                0.030s                0.166s   2021-11-23 20:25:09
#          82                   200                0.003s                0.165s   2021-11-23 20:25:10
#          83                   200                0.019s                0.173s   2021-11-23 20:25:10
#          84                   200                0.053s                0.291s   2021-11-23 20:25:10
#          85                   200                0.081s                0.269s   2021-11-23 20:25:10
#          86                   200                0.085s                0.191s   2021-11-23 20:25:11
#          87                   200                0.064s                0.215s   2021-11-23 20:25:11
#          88                   200                0.059s                0.190s   2021-11-23 20:25:11
#          89                   200                0.044s                0.182s   2021-11-23 20:25:11
#          90                   200                0.093s                0.215s   2021-11-23 20:25:12
#          91                   200                0.096s                0.152s   2021-11-23 20:25:12
#          92                   200                0.044s                0.212s   2021-11-23 20:25:12
#          93                   200                0.007s                0.247s   2021-11-23 20:25:13
#          94                   200                0.033s                0.272s   2021-11-23 20:25:13
#          95                   200                0.010s                0.261s   2021-11-23 20:25:13
#          96                   200                0.037s                0.156s   2021-11-23 20:25:13
#          97                   200                0.003s                0.178s   2021-11-23 20:25:14
#          98                   200                0.091s                0.198s   2021-11-23 20:25:14
#          99                   200                0.005s                0.152s   2021-11-23 20:25:14
#         100                   200                0.092s                0.206s   2021-11-23 20:25:14
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-1 : All tests passed!
#
# (Thread-3) Stress Test with [100] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/flyingpigeon/wps?service=wps&request=getcapabilities]
# Stress Test:
#     Test:
#         code: 200
#         runs: 100
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/flyingpigeon/wps?service=wps&request=getcapabilities
#         args:   {}
#     Times:
#         min: 0.128s
#         avg: 0.194s
#         max: 0.292s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.260s   2021-11-23 20:24:50
#           2                   200                0.054s                0.202s   2021-11-23 20:24:50
#           3                   200                0.096s                0.154s   2021-11-23 20:24:50
#           4                   200                0.060s                0.148s   2021-11-23 20:24:51
#           5                   200                0.041s                0.152s   2021-11-23 20:24:51
#           6                   200                0.074s                0.176s   2021-11-23 20:24:51
#           7                   200                0.004s                0.228s   2021-11-23 20:24:51
#           8                   200                0.094s                0.165s   2021-11-23 20:24:51
#           9                   200                0.100s                0.186s   2021-11-23 20:24:52
#          10                   200                0.080s                0.202s   2021-11-23 20:24:52
#          11                   200                0.062s                0.289s   2021-11-23 20:24:52
#          12                   200                0.036s                0.178s   2021-11-23 20:24:53
#          13                   200                0.003s                0.231s   2021-11-23 20:24:53
#          14                   200                0.080s                0.153s   2021-11-23 20:24:53
#          15                   200                0.039s                0.164s   2021-11-23 20:24:53
#          16                   200                0.093s                0.242s   2021-11-23 20:24:54
#          17                   200                0.036s                0.196s   2021-11-23 20:24:54
#          18                   200                0.089s                0.128s   2021-11-23 20:24:54
#          19                   200                0.016s                0.181s   2021-11-23 20:24:54
#          20                   200                0.014s                0.211s   2021-11-23 20:24:55
#          21                   200                0.072s                0.231s   2021-11-23 20:24:55
#          22                   200                0.057s                0.173s   2021-11-23 20:24:55
# ...
#          52                   200                0.021s                0.123s   2021-11-23 20:26:12
#          53                   200                0.010s                0.182s   2021-11-23 20:26:12
#          54                   200                0.036s                0.142s   2021-11-23 20:26:13
#          55                   200                0.056s                0.168s   2021-11-23 20:26:13
#          56                   200                0.099s                0.147s   2021-11-23 20:26:13
#          57                   200                0.054s                0.150s   2021-11-23 20:26:13
#          58                   200                0.010s                0.149s   2021-11-23 20:26:13
#          59                   200                0.076s                0.126s   2021-11-23 20:26:14
#          60                   200                0.086s                0.127s   2021-11-23 20:26:14
#          61                   200                0.067s                0.164s   2021-11-23 20:26:14
#          62                   200                0.011s                0.126s   2021-11-23 20:26:14
#          63                   200                0.005s                0.125s   2021-11-23 20:26:14
#          64                   200                0.013s                0.146s   2021-11-23 20:26:14
#          65                   200                0.047s                0.142s   2021-11-23 20:26:15
#          66                   200                0.087s                0.144s   2021-11-23 20:26:15
#          67                   200                0.088s                0.163s   2021-11-23 20:26:15
#          68                   200                0.059s                0.143s   2021-11-23 20:26:15
#          69                   200                0.051s                0.141s   2021-11-23 20:26:15
#          70                   200                0.035s                0.165s   2021-11-23 20:26:16
#          71                   200                0.065s                0.157s   2021-11-23 20:26:16
#          72                   200                0.074s                0.154s   2021-11-23 20:26:16
#          73                   200                0.027s                0.133s   2021-11-23 20:26:16
#          74                   200                0.028s                0.186s   2021-11-23 20:26:17
#          75                   200                0.100s                0.145s   2021-11-23 20:26:17
#          76                   200                0.090s                0.187s   2021-11-23 20:26:17
#          77                   200                0.024s                0.153s   2021-11-23 20:26:17
#          78                   200                0.004s                0.158s   2021-11-23 20:26:17
#          79                   200                0.073s                0.103s   2021-11-23 20:26:18
#          80                   200                0.002s                0.098s   2021-11-23 20:26:18
#          81                   200                0.017s                0.185s   2021-11-23 20:26:18
#          82                   200                0.035s                0.149s   2021-11-23 20:26:18
#          83                   200                0.036s                0.191s   2021-11-23 20:26:18
#          84                   200                0.009s                0.147s   2021-11-23 20:26:18
#          85                   200                0.066s                0.116s   2021-11-23 20:26:19
#          86                   200                0.073s                0.123s   2021-11-23 20:26:19
#          87                   200                0.067s                0.223s   2021-11-23 20:26:19
#          88                   200                0.090s                0.198s   2021-11-23 20:26:19
#          89                   200                0.031s                0.116s   2021-11-23 20:26:20
#          90                   200                0.095s                0.125s   2021-11-23 20:26:20
#          91                   200                0.048s                0.102s   2021-11-23 20:26:20
#          92                   200                0.046s                0.150s   2021-11-23 20:26:20
#          93                   200                0.098s                0.114s   2021-11-23 20:26:20
#          94                   200                0.056s                0.123s   2021-11-23 20:26:20
#          95                   200                0.071s                0.161s   2021-11-23 20:26:21
#          96                   200                0.050s                0.171s   2021-11-23 20:26:21
#          97                   200                0.010s                0.118s   2021-11-23 20:26:21
#          98                   200                0.033s                0.200s   2021-11-23 20:26:21
#          99                   200                0.019s                0.128s   2021-11-23 20:26:21
#         100                   200                0.043s                0.133s   2021-11-23 20:26:22
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-1 : All tests passed!
# (Thread-3) Stress Test with [100] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/hummingbird/wps?service=wps&request=getcapabilities]
# Stress Test:
#     Test:
#         code: 200
#         runs: 100
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/hummingbird/wps?service=wps&request=getcapabilities
#         args:   {}
#     Times:
#         min: 0.100s
#         avg: 0.151s
#         max: 0.236s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.196s   2021-11-23 20:26:02
#           2                   200                0.096s                0.155s   2021-11-23 20:26:02
#           3                   200                0.037s                0.217s   2021-11-23 20:26:02
#           4                   200                0.039s                0.145s   2021-11-23 20:26:03
#           5                   200                0.045s                0.105s   2021-11-23 20:26:03
#           6                   200                0.071s                0.141s   2021-11-23 20:26:03
#           7                   200                0.056s                0.137s   2021-11-23 20:26:03
#           8                   200                0.083s                0.138s   2021-11-23 20:26:03
#           9                   200                0.032s                0.122s   2021-11-23 20:26:03
#          10                   200                0.031s                0.159s   2021-11-23 20:26:04
#          11                   200                0.009s                0.169s   2021-11-23 20:26:04
#          12                   200                0.083s                0.131s   2021-11-23 20:26:04
#          13                   200                0.020s                0.129s   2021-11-23 20:26:04
#          14                   200                0.075s                0.147s   2021-11-23 20:26:04
#          15                   200                0.034s                0.205s   2021-11-23 20:26:05
#          16                   200                0.096s                0.160s   2021-11-23 20:26:05
#          17                   200                0.099s                0.143s   2021-11-23 20:26:05
#          18                   200                0.006s                0.137s   2021-11-23 20:26:05
#          19                   200                0.009s                0.130s   2021-11-23 20:26:05
#          20                   200                0.086s                0.177s   2021-11-23 20:26:06
#          21                   200                0.065s                0.169s   2021-11-23 20:26:06
#          22                   200                0.036s                0.204s   2021-11-23 20:26:06
#          23                   200                0.097s                0.186s   2021-11-23 20:26:06
#          24                   200                0.062s                0.129s   2021-11-23 20:26:07
#          25                   200                0.040s                0.236s   2021-11-23 20:26:07
#          26                   200                0.043s                0.126s   2021-11-23 20:26:07
#          27                   200                0.052s                0.199s   2021-11-23 20:26:07
#          28                   200                0.037s                0.145s   2021-11-23 20:26:08
#          29                   200                0.074s                0.169s   2021-11-23 20:26:08
#          30                   200                0.095s                0.136s   2021-11-23 20:26:08
#          31                   200                0.087s                0.135s   2021-11-23 20:26:08
#          32                   200                0.074s                0.104s   2021-11-23 20:26:08
#          33                   200                0.063s                0.103s   2021-11-23 20:26:09
#          34                   200                0.092s                0.129s   2021-11-23 20:26:09
#          35                   200                0.035s                0.132s   2021-11-23 20:26:09
#          36                   200                0.006s                0.144s   2021-11-23 20:26:09
#          37                   200                0.085s                0.131s   2021-11-23 20:26:09
#          38                   200                0.082s                0.183s   2021-11-23 20:26:10
#          39                   200                0.012s                0.156s   2021-11-23 20:26:10
#          40                   200                0.042s                0.138s   2021-11-23 20:26:10
#          41                   200                0.003s                0.148s   2021-11-23 20:26:10
#          42                   200                0.097s                0.119s   2021-11-23 20:26:10
#          43                   200                0.071s                0.121s   2021-11-23 20:26:10
#          44                   200                0.087s                0.150s   2021-11-23 20:26:11
#          45                   200                0.019s                0.165s   2021-11-23 20:26:11
#          46                   200                0.043s                0.169s   2021-11-23 20:26:11
#          47                   200                0.059s                0.163s   2021-11-23 20:26:11
#          48                   200                0.088s                0.195s   2021-11-23 20:26:12
#          49                   200                0.076s                0.119s   2021-11-23 20:26:12
#          50                   200                0.020s                0.120s   2021-11-23 20:26:12
#          51                   200                0.027s                0.136s   2021-11-23 20:26:12
#          52                   200                0.050s                0.178s   2021-11-23 20:26:12
#          53                   200                0.022s                0.147s   2021-11-23 20:26:13
#          54                   200                0.039s                0.175s   2021-11-23 20:26:13
#          55                   200                0.050s                0.149s   2021-11-23 20:26:13
#          56                   200                0.091s                0.140s   2021-11-23 20:26:13
#          57                   200                0.046s                0.161s   2021-11-23 20:26:13
#          58                   200                0.089s                0.130s   2021-11-23 20:26:14
#          59                   200                0.010s                0.141s   2021-11-23 20:26:14
#          60                   200                0.010s                0.172s   2021-11-23 20:26:14
#          61                   200                0.041s                0.132s   2021-11-23 20:26:14
#          62                   200                0.085s                0.148s   2021-11-23 20:26:14
#          63                   200                0.078s                0.168s   2021-11-23 20:26:15
#          64                   200                0.077s                0.146s   2021-11-23 20:26:15
#          65                   200                0.072s                0.190s   2021-11-23 20:26:15
#          66                   200                0.005s                0.161s   2021-11-23 20:26:15
#          67                   200                0.005s                0.138s   2021-11-23 20:26:15
#          68                   200                0.030s                0.100s   2021-11-23 20:26:16
#          69                   200                0.083s                0.158s   2021-11-23 20:26:16
#          70                   200                0.061s                0.122s   2021-11-23 20:26:16
#          71                   200                0.090s                0.141s   2021-11-23 20:26:16
#          72                   200                0.021s                0.130s   2021-11-23 20:26:16
#          73                   200                0.087s                0.175s   2021-11-23 20:26:17
#          74                   200                0.033s                0.153s   2021-11-23 20:26:17
#          75                   200                0.018s                0.174s   2021-11-23 20:26:17
#          76                   200                0.014s                0.145s   2021-11-23 20:26:17
#          77                   200                0.039s                0.157s   2021-11-23 20:26:17
#          78                   200                0.031s                0.144s   2021-11-23 20:26:18
#          79                   200                0.037s                0.135s   2021-11-23 20:26:18
#          80                   200                0.065s                0.167s   2021-11-23 20:26:18
#          81                   200                0.021s                0.168s   2021-11-23 20:26:18
#          82                   200                0.095s                0.148s   2021-11-23 20:26:18
#          83                   200                0.100s                0.129s   2021-11-23 20:26:19
#          84                   200                0.084s                0.123s   2021-11-23 20:26:19
#          85                   200                0.092s                0.233s   2021-11-23 20:26:19
#          86                   200                0.010s                0.175s   2021-11-23 20:26:19
#          87                   200                0.034s                0.123s   2021-11-23 20:26:19
#          88                   200                0.094s                0.159s   2021-11-23 20:26:20
#          89                   200                0.029s                0.134s   2021-11-23 20:26:20
#          90                   200                0.085s                0.131s   2021-11-23 20:26:20
#          91                   200                0.092s                0.132s   2021-11-23 20:26:20
#          92                   200                0.043s                0.163s   2021-11-23 20:26:21
#          93                   200                0.011s                0.152s   2021-11-23 20:26:21
#          94                   200                0.060s                0.161s   2021-11-23 20:26:21
#          95                   200                0.019s                0.132s   2021-11-23 20:26:21
#          96                   200                0.032s                0.149s   2021-11-23 20:26:21
#          97                   200                0.085s                0.131s   2021-11-23 20:26:21
#          98                   200                0.004s                0.147s   2021-11-23 20:26:22
#          99                   200                0.032s                0.148s   2021-11-23 20:26:22
#         100                   200                0.039s                0.138s   2021-11-23 20:26:22
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-3 : All tests passed!
# All threads passed stress_test function.

# %%
# NBVAL_IGNORE_OUTPUT

# Executing THREDDS test on multiple threads
thredds_url = f"{TWITCHER_URL}/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc"

run_threads(target_test = stress_test,
            url = thredds_url,
            n_threads = TEST_N_THREADS_THREDDS,
            runs_per_threads = TEST_RUNS_THREDDS)
# Out:
# --------------------------------------------------------------------------------------------------------
# URL Execution-1
# - Starting 5 threads with 500 runs per threads targeting "stress_test" function.
# - URL : https://pavics.ouranos.ca/twitcher/ows/proxy/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc
# - Initial progression values : {'count': 0, 'n_threads': 5, 'runs_per_threads': 500, 'total_runs': 2500, 'failed_threads_count': 0, 'failed_requests_count': 0, 'failed_stress_test_results': []}
# --------------------------------------------------------------------------------------------------------
#     Thread-3 --> Progress : 50/2500
#     Thread-1 --> Progress : 100/2500
#     Thread-2 --> Progress : 150/2500
#     Thread-5 --> Progress : 200/2500
#     Thread-4 --> Progress : 250/2500
#     Thread-5 --> Progress : 300/2500
#     Thread-3 --> Progress : 350/2500
#     Thread-2 --> Progress : 400/2500
#     Thread-1 --> Progress : 450/2500
#     Thread-4 --> Progress : 500/2500
#     Thread-5 --> Progress : 550/2500
#     Thread-4 --> Progress : 600/2500
#     Thread-2 --> Progress : 650/2500
#     Thread-3 --> Progress : 700/2500
#     Thread-1 --> Progress : 750/2500
#     Thread-5 --> Progress : 800/2500
#     Thread-3 --> Progress : 850/2500
#     Thread-4 --> Progress : 900/2500
#     Thread-2 --> Progress : 950/2500
#     Thread-1 --> Progress : 1000/2500
#     Thread-3 --> Progress : 1050/2500
#     Thread-5 --> Progress : 1100/2500
#     Thread-2 --> Progress : 1150/2500
#     Thread-4 --> Progress : 1200/2500
#     Thread-1 --> Progress : 1250/2500
#     Thread-5 --> Progress : 1300/2500
#     Thread-2 --> Progress : 1350/2500
#     Thread-3 --> Progress : 1400/2500
#     Thread-4 --> Progress : 1450/2500
#     Thread-1 --> Progress : 1500/2500
#     Thread-5 --> Progress : 1550/2500
#     Thread-2 --> Progress : 1600/2500
#     Thread-3 --> Progress : 1650/2500
#     Thread-4 --> Progress : 1700/2500
#     Thread-1 --> Progress : 1750/2500
#     Thread-5 --> Progress : 1800/2500
#     Thread-2 --> Progress : 1850/2500
#     Thread-3 --> Progress : 1900/2500
#     Thread-4 --> Progress : 1950/2500
#     Thread-1 --> Progress : 2000/2500
#     Thread-5 --> Progress : 2050/2500
#     Thread-4 --> Progress : 2100/2500
#     Thread-2 --> Progress : 2150/2500
#     Thread-3 --> Progress : 2200/2500
#     Thread-1 --> Progress : 2250/2500
#     Thread-5 --> Progress : 2300/2500
#     Thread-2 --> Progress : 2350/2500
#     Thread-3 --> Progress : 2400/2500
#     Thread-4 --> Progress : 2450/2500
#     Thread-1 --> Progress : 2500/2500
#
# (Thread-5) Stress Test with [500] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc]
# Stress Test:
#     Test:
#         code: 200
#         runs: 500
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc
#         args:   {}
#     Times:
#         min: 0.117s
#         avg: 0.248s
#         max: 0.437s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.367s   2021-11-23 20:26:22
#           2                   200                0.012s                0.263s   2021-11-23 20:26:23
#           3                   200                0.002s                0.215s   2021-11-23 20:26:23
#           4                   200                0.093s                0.193s   2021-11-23 20:26:23
#           5                   200                0.030s                0.200s   2021-11-23 20:26:23
#           6                   200                0.082s                0.204s   2021-11-23 20:26:24
#           7                   200                0.071s                0.282s   2021-11-23 20:26:24
#           8                   200                0.039s                0.301s   2021-11-23 20:26:24
#           9                   200                0.043s                0.208s   2021-11-23 20:26:25
#          10                   200                0.043s                0.192s   2021-11-23 20:26:25
#          11                   200                0.043s                0.184s   2021-11-23 20:26:25
#          12                   200                0.007s                0.298s   2021-11-23 20:26:25
#          13                   200                0.022s                0.275s   2021-11-23 20:26:26
#          14                   200                0.038s                0.226s   2021-11-23 20:26:26
#          15                   200                0.035s                0.168s   2021-11-23 20:26:26
#          16                   200                0.012s                0.313s   2021-11-23 20:26:26
#          17                   200                0.064s                0.192s   2021-11-23 20:26:27
#          18                   200                0.069s                0.193s   2021-11-23 20:26:27
#          19                   200                0.046s                0.266s   2021-11-23 20:26:27
#          20                   200                0.040s                0.195s   2021-11-23 20:26:28
#          21                   200                0.065s                0.162s   2021-11-23 20:26:28
#          22                   200                0.012s                0.251s   2021-11-23 20:26:28
#          23                   200                0.048s                0.301s   2021-11-23 20:26:28
#          24                   200                0.082s                0.246s   2021-11-23 20:26:29
#          25                   200                0.051s                0.186s   2021-11-23 20:26:29
#          26                   200                0.009s                0.277s   2021-11-23 20:26:29
#          27                   200                0.094s                0.173s   2021-11-23 20:26:29
#          28                   200                0.023s                0.239s   2021-11-23 20:26:30
#          29                   200                0.083s                0.160s   2021-11-23 20:26:30
#          30                   200                0.014s                0.133s   2021-11-23 20:26:30
#          31                   200                0.019s                0.190s   2021-11-23 20:26:30
#          32                   200                0.040s                0.235s   2021-11-23 20:26:31
#          33                   200                0.023s                0.239s   2021-11-23 20:26:31
#          34                   200                0.002s                0.187s   2021-11-23 20:26:31
#          35                   200                0.031s                0.209s   2021-11-23 20:26:31
#          36                   200                0.093s                0.204s   2021-11-23 20:26:32
#          37                   200                0.098s                0.228s   2021-11-23 20:26:32
#          38                   200                0.005s                0.226s   2021-11-23 20:26:32
#          39                   200                0.085s                0.163s   2021-11-23 20:26:32
#          40                   200                0.097s                0.247s   2021-11-23 20:26:33
#          41                   200                0.005s                0.282s   2021-11-23 20:26:33
#          42                   200                0.013s                0.293s   2021-11-23 20:26:33
#          43                   200                0.067s                0.289s   2021-11-23 20:26:34
#          44                   200                0.022s                0.289s   2021-11-23 20:26:34
#          45                   200                0.034s                0.254s   2021-11-23 20:26:34
#          46                   200                0.031s                0.212s   2021-11-23 20:26:35
#          47                   200                0.014s                0.242s   2021-11-23 20:26:35
#          48                   200                0.097s                0.261s   2021-11-23 20:26:35
#          49                   200                0.017s                0.303s   2021-11-23 20:26:36
#          50                   200                0.021s                0.246s   2021-11-23 20:26:36
#          51                   200                0.051s                0.273s   2021-11-23 20:26:36
#          52                   200                0.060s                0.185s   2021-11-23 20:26:36
#          53                   200                0.048s                0.215s   2021-11-23 20:26:37
#          54                   200                0.028s                0.261s   2021-11-23 20:26:37
#          55                   200                0.066s                0.216s   2021-11-23 20:26:37
#          56                   200                0.072s                0.271s   2021-11-23 20:26:37
#          57                   200                0.032s                0.209s   2021-11-23 20:26:38
#          58                   200                0.075s                0.210s   2021-11-23 20:26:38
#          59                   200                0.056s                0.296s   2021-11-23 20:26:38
#          60                   200                0.014s                0.253s   2021-11-23 20:26:39
#          61                   200                0.078s                0.237s   2021-11-23 20:26:39
#          62                   200                0.027s                0.257s   2021-11-23 20:26:39
#          63                   200                0.069s                0.152s   2021-11-23 20:26:39
#          64                   200                0.023s                0.306s   2021-11-23 20:26:40
#          65                   200                0.010s                0.240s   2021-11-23 20:26:40
#          66                   200                0.030s                0.208s   2021-11-23 20:26:40
#          67                   200                0.016s                0.269s   2021-11-23 20:26:41
#          68                   200                0.086s                0.347s   2021-11-23 20:26:41
#          69                   200                0.088s                0.178s   2021-11-23 20:26:41
#          70                   200                0.025s                0.233s   2021-11-23 20:26:42
#          71                   200                0.059s                0.297s   2021-11-23 20:26:42
#          72                   200                0.090s                0.229s   2021-11-23 20:26:42
#          73                   200                0.067s                0.300s   2021-11-23 20:26:43
#          74                   200                0.048s                0.202s   2021-11-23 20:26:43
#          75                   200                0.100s                0.288s   2021-11-23 20:26:43
#          76                   200                0.073s                0.249s   2021-11-23 20:26:44
#          77                   200                0.072s                0.276s   2021-11-23 20:26:44
#          78                   200                0.045s                0.223s   2021-11-23 20:26:44
#          79                   200                0.052s                0.171s   2021-11-23 20:26:44
#          80                   200                0.060s                0.306s   2021-11-23 20:26:45
#          81                   200                0.080s                0.245s   2021-11-23 20:26:45
#          82                   200                0.052s                0.329s   2021-11-23 20:26:45
#          83                   200                0.047s                0.270s   2021-11-23 20:26:46
#          84                   200                0.006s                0.280s   2021-11-23 20:26:46
#          85                   200                0.026s                0.316s   2021-11-23 20:26:46
#          86                   200                0.077s                0.218s   2021-11-23 20:26:47
#          87                   200                0.055s                0.178s   2021-11-23 20:26:47
#          88                   200                0.062s                0.310s   2021-11-23 20:26:47
#          89                   200                0.002s                0.271s   2021-11-23 20:26:48
#          90                   200                0.097s                0.246s   2021-11-23 20:26:48
#          91                   200                0.010s                0.204s   2021-11-23 20:26:48
#          92                   200                0.087s                0.191s   2021-11-23 20:26:48
#          93                   200                0.065s                0.219s   2021-11-23 20:26:49
#          94                   200                0.070s                0.305s   2021-11-23 20:26:49
#          95                   200                0.090s                0.225s   2021-11-23 20:26:49
#          96                   200                0.065s                0.289s   2021-11-23 20:26:50
#          97                   200                0.037s                0.216s   2021-11-23 20:26:50
#          98                   200                0.003s                0.291s   2021-11-23 20:26:50
#          99                   200                0.026s                0.315s   2021-11-23 20:26:51
#         100                   200                0.002s                0.187s   2021-11-23 20:26:51
#         101                   200                0.006s                0.261s   2021-11-23 20:26:51
#         102                   200                0.093s                0.331s   2021-11-23 20:26:51
#         103                   200                0.029s                0.223s   2021-11-23 20:26:52
#         104                   200                0.027s                0.239s   2021-11-23 20:26:52
#         105                   200                0.014s                0.262s   2021-11-23 20:26:52
#         106                   200                0.071s                0.285s   2021-11-23 20:26:53
#         107                   200                0.005s                0.188s   2021-11-23 20:26:53
#         108                   200                0.063s                0.197s   2021-11-23 20:26:53
#         109                   200                0.008s                0.254s   2021-11-23 20:26:53
#         110                   200                0.001s                0.278s   2021-11-23 20:26:54
#         111                   200                0.016s                0.254s   2021-11-23 20:26:54
#         112                   200                0.033s                0.280s   2021-11-23 20:26:54
#         113                   200                0.011s                0.234s   2021-11-23 20:26:55
#         114                   200                0.100s                0.270s   2021-11-23 20:26:55
#         115                   200                0.060s                0.137s   2021-11-23 20:26:55
#         116                   200                0.039s                0.240s   2021-11-23 20:26:55
#         117                   200                0.010s                0.288s   2021-11-23 20:26:56
#         118                   200                0.057s                0.230s   2021-11-23 20:26:56
#         119                   200                0.020s                0.234s   2021-11-23 20:26:56
#         120                   200                0.074s                0.199s   2021-11-23 20:26:56
#         121                   200                0.093s                0.243s   2021-11-23 20:26:57
#         122                   200                0.026s                0.234s   2021-11-23 20:26:57
#         123                   200                0.044s                0.185s   2021-11-23 20:26:57
#         124                   200                0.012s                0.413s   2021-11-23 20:26:58
#         125                   200                0.065s                0.271s   2021-11-23 20:26:58
#         126                   200                0.016s                0.199s   2021-11-23 20:26:58
#         127                   200                0.069s                0.283s   2021-11-23 20:26:59
#         128                   200                0.085s                0.317s   2021-11-23 20:26:59
#         129                   200                0.082s                0.280s   2021-11-23 20:26:59
#         130                   200                0.097s                0.252s   2021-11-23 20:27:00
#         131                   200                0.084s                0.279s   2021-11-23 20:27:00
#         132                   200                0.054s                0.272s   2021-11-23 20:27:00
#         133                   200                0.001s                0.235s   2021-11-23 20:27:01
#         134                   200                0.020s                0.157s   2021-11-23 20:27:01
#         135                   200                0.008s                0.278s   2021-11-23 20:27:01
#         136                   200                0.082s                0.257s   2021-11-23 20:27:01
#         137                   200                0.085s                0.213s   2021-11-23 20:27:02
#         138                   200                0.034s                0.214s   2021-11-23 20:27:02
#         139                   200                0.094s                0.278s   2021-11-23 20:27:02
#         140                   200                0.099s                0.269s   2021-11-23 20:27:03
#         141                   200                0.096s                0.273s   2021-11-23 20:27:03
#         142                   200                0.032s                0.316s   2021-11-23 20:27:04
#         143                   200                0.025s                0.364s   2021-11-23 20:27:04
#         144                   200                0.032s                0.334s   2021-11-23 20:27:04
#         145                   200                0.094s                0.268s   2021-11-23 20:27:05
#         146                   200                0.015s                0.287s   2021-11-23 20:27:05
#         147                   200                0.032s                0.319s   2021-11-23 20:27:05
#         148                   200                0.053s                0.242s   2021-11-23 20:27:06
#         149                   200                0.038s                0.241s   2021-11-23 20:27:06
#         150                   200                0.059s                0.200s   2021-11-23 20:27:06
#         151                   200                0.054s                0.254s   2021-11-23 20:27:06
#         152                   200                0.047s                0.294s   2021-11-23 20:27:07
#         153                   200                0.021s                0.281s   2021-11-23 20:27:07
#         154                   200                0.026s                0.221s   2021-11-23 20:27:07
#         155                   200                0.076s                0.295s   2021-11-23 20:27:08
#         156                   200                0.079s                0.290s   2021-11-23 20:27:08
#         157                   200                0.070s                0.249s   2021-11-23 20:27:08
#         158                   200                0.004s                0.222s   2021-11-23 20:27:09
#         159                   200                0.014s                0.171s   2021-11-23 20:27:09
#         160                   200                0.077s                0.209s   2021-11-23 20:27:09
#         161                   200                0.021s                0.371s   2021-11-23 20:27:09
#         162                   200                0.093s                0.251s   2021-11-23 20:27:10
#         163                   200                0.011s                0.221s   2021-11-23 20:27:10
#         164                   200                0.061s                0.250s   2021-11-23 20:27:10
#         165                   200                0.059s                0.259s   2021-11-23 20:27:11
#         166                   200                0.056s                0.267s   2021-11-23 20:27:11
#         167                   200                0.085s                0.291s   2021-11-23 20:27:11
#         168                   200                0.076s                0.201s   2021-11-23 20:27:12
#         169                   200                0.076s                0.200s   2021-11-23 20:27:12
#         170                   200                0.097s                0.158s   2021-11-23 20:27:12
#         171                   200                0.081s                0.250s   2021-11-23 20:27:12
#         172                   200                0.032s                0.291s   2021-11-23 20:27:13
#         173                   200                0.020s                0.237s   2021-11-23 20:27:13
#         174                   200                0.081s                0.221s   2021-11-23 20:27:13
#         175                   200                0.081s                0.289s   2021-11-23 20:27:14
#         176                   200                0.043s                0.238s   2021-11-23 20:27:14
#         177                   200                0.031s                0.254s   2021-11-23 20:27:14
#         178                   200                0.032s                0.317s   2021-11-23 20:27:15
#         179                   200                0.016s                0.266s   2021-11-23 20:27:15
#         180                   200                0.046s                0.296s   2021-11-23 20:27:15
#         181                   200                0.009s                0.235s   2021-11-23 20:27:16
#         182                   200                0.035s                0.193s   2021-11-23 20:27:16
#         183                   200                0.045s                0.225s   2021-11-23 20:27:16
#         184                   200                0.093s                0.241s   2021-11-23 20:27:16
#         185                   200                0.072s                0.298s   2021-11-23 20:27:17
#         186                   200                0.078s                0.266s   2021-11-23 20:27:17
#         187                   200                0.007s                0.265s   2021-11-23 20:27:17
#         188                   200                0.082s                0.275s   2021-11-23 20:27:18
#         189                   200                0.079s                0.262s   2021-11-23 20:27:18
#         190                   200                0.006s                0.212s   2021-11-23 20:27:18
#         191                   200                0.053s                0.262s   2021-11-23 20:27:19
#         192                   200                0.054s                0.259s   2021-11-23 20:27:19
#         193                   200                0.046s                0.333s   2021-11-23 20:27:19
#         194                   200                0.074s                0.307s   2021-11-23 20:27:20
#         195                   200                0.078s                0.195s   2021-11-23 20:27:20
#         196                   200                0.015s                0.247s   2021-11-23 20:27:20
#         197                   200                0.027s                0.243s   2021-11-23 20:27:20
#         198                   200                0.081s                0.231s   2021-11-23 20:27:21
#         199                   200                0.079s                0.216s   2021-11-23 20:27:21
#         200                   200                0.013s                0.296s   2021-11-23 20:27:21
#         201                   200                0.064s                0.225s   2021-11-23 20:27:22
#         202                   200                0.093s                0.237s   2021-11-23 20:27:22
#         203                   200                0.054s                0.301s   2021-11-23 20:27:22
#         204                   200                0.015s                0.262s   2021-11-23 20:27:23
#         205                   200                0.004s                0.250s   2021-11-23 20:27:23
#         206                   200                0.009s                0.257s   2021-11-23 20:27:23
#         207                   200                0.090s                0.253s   2021-11-23 20:27:23
#         208                   200                0.036s                0.306s   2021-11-23 20:27:24
#         209                   200                0.027s                0.150s   2021-11-23 20:27:24
#         210                   200                0.025s                0.242s   2021-11-23 20:27:24
#         211                   200                0.036s                0.357s   2021-11-23 20:27:25
#         212                   200                0.016s                0.270s   2021-11-23 20:27:25
#         213                   200                0.012s                0.286s   2021-11-23 20:27:25
#         214                   200                0.060s                0.244s   2021-11-23 20:27:26
#         215                   200                0.079s                0.232s   2021-11-23 20:27:26
#         216                   200                0.090s                0.129s   2021-11-23 20:27:26
#         217                   200                0.026s                0.288s   2021-11-23 20:27:26
#         218                   200                0.014s                0.248s   2021-11-23 20:27:27
#         219                   200                0.023s                0.213s   2021-11-23 20:27:27
#         220                   200                0.038s                0.232s   2021-11-23 20:27:27
#         221                   200                0.092s                0.214s   2021-11-23 20:27:27
#         222                   200                0.068s                0.149s   2021-11-23 20:27:28
#         223                   200                0.078s                0.313s   2021-11-23 20:27:28
#         224                   200                0.035s                0.273s   2021-11-23 20:27:28
#         225                   200                0.029s                0.257s   2021-11-23 20:27:29
#         226                   200                0.018s                0.304s   2021-11-23 20:27:29
#         227                   200                0.039s                0.239s   2021-11-23 20:27:29
#         228                   200                0.081s                0.266s   2021-11-23 20:27:30
#         229                   200                0.043s                0.200s   2021-11-23 20:27:30
#         230                   200                0.055s                0.341s   2021-11-23 20:27:30
#         231                   200                0.002s                0.232s   2021-11-23 20:27:31
#         232                   200                0.006s                0.255s   2021-11-23 20:27:31
#         233                   200                0.003s                0.264s   2021-11-23 20:27:31
#         234                   200                0.059s                0.192s   2021-11-23 20:27:31
#         235                   200                0.037s                0.192s   2021-11-23 20:27:32
#         236                   200                0.051s                0.280s   2021-11-23 20:27:32
#         237                   200                0.013s                0.382s   2021-11-23 20:27:32
#         238                   200                0.088s                0.296s   2021-11-23 20:27:33
#         239                   200                0.043s                0.212s   2021-11-23 20:27:33
#         240                   200                0.003s                0.237s   2021-11-23 20:27:33
#         241                   200                0.002s                0.229s   2021-11-23 20:27:33
#         242                   200                0.074s                0.258s   2021-11-23 20:27:34
#         243                   200                0.008s                0.175s   2021-11-23 20:27:34
#         244                   200                0.071s                0.251s   2021-11-23 20:27:34
#         245                   200                0.018s                0.271s   2021-11-23 20:27:35
#         246                   200                0.071s                0.272s   2021-11-23 20:27:35
#         247                   200                0.068s                0.247s   2021-11-23 20:27:35
#         248                   200                0.067s                0.237s   2021-11-23 20:27:35
#         249                   200                0.085s                0.133s   2021-11-23 20:27:36
#         250                   200                0.006s                0.212s   2021-11-23 20:27:36
#         251                   200                0.031s                0.216s   2021-11-23 20:27:36
#         252                   200                0.076s                0.250s   2021-11-23 20:27:36
#         253                   200                0.021s                0.316s   2021-11-23 20:27:37
#         254                   200                0.065s                0.237s   2021-11-23 20:27:37
#         255                   200                0.083s                0.134s   2021-11-23 20:27:37
#         256                   200                0.025s                0.256s   2021-11-23 20:27:38
#         257                   200                0.080s                0.393s   2021-11-23 20:27:38
#         258                   200                0.078s                0.201s   2021-11-23 20:27:38
#         259                   200                0.001s                0.207s   2021-11-23 20:27:39
#         260                   200                0.020s                0.175s   2021-11-23 20:27:39
#         261                   200                0.031s                0.217s   2021-11-23 20:27:39
#         262                   200                0.069s                0.223s   2021-11-23 20:27:39
#         263                   200                0.098s                0.242s   2021-11-23 20:27:40
#         264                   200                0.090s                0.143s   2021-11-23 20:27:40
#         265                   200                0.009s                0.171s   2021-11-23 20:27:40
#         266                   200                0.017s                0.222s   2021-11-23 20:27:40
#         267                   200                0.004s                0.189s   2021-11-23 20:27:41
#         268                   200                0.016s                0.235s   2021-11-23 20:27:41
#         269                   200                0.030s                0.230s   2021-11-23 20:27:41
#         270                   200                0.006s                0.245s   2021-11-23 20:27:41
#         271                   200                0.008s                0.290s   2021-11-23 20:27:42
#         272                   200                0.041s                0.248s   2021-11-23 20:27:42
#         273                   200                0.021s                0.219s   2021-11-23 20:27:42
#         274                   200                0.035s                0.179s   2021-11-23 20:27:42
#         275                   200                0.061s                0.214s   2021-11-23 20:27:43
#         276                   200                0.068s                0.253s   2021-11-23 20:27:43
#         277                   200                0.055s                0.267s   2021-11-23 20:27:43
#         278                   200                0.027s                0.359s   2021-11-23 20:27:44
#         279                   200                0.047s                0.255s   2021-11-23 20:27:44
#         280                   200                0.008s                0.238s   2021-11-23 20:27:44
#         281                   200                0.061s                0.312s   2021-11-23 20:27:45
#         282                   200                0.065s                0.263s   2021-11-23 20:27:45
#         283                   200                0.004s                0.229s   2021-11-23 20:27:45
#         284                   200                0.047s                0.243s   2021-11-23 20:27:45
#         285                   200                0.046s                0.237s   2021-11-23 20:27:46
#         286                   200                0.001s                0.238s   2021-11-23 20:27:46
#         287                   200                0.083s                0.273s   2021-11-23 20:27:46
#         288                   200                0.074s                0.223s   2021-11-23 20:27:47
#         289                   200                0.039s                0.290s   2021-11-23 20:27:47
#         290                   200                0.081s                0.247s   2021-11-23 20:27:47
#         291                   200                0.032s                0.225s   2021-11-23 20:27:48
#         292                   200                0.068s                0.216s   2021-11-23 20:27:48
#         293                   200                0.043s                0.201s   2021-11-23 20:27:48
#         294                   200                0.013s                0.243s   2021-11-23 20:27:48
#         295                   200                0.045s                0.242s   2021-11-23 20:27:49
#         296                   200                0.057s                0.155s   2021-11-23 20:27:49
#         297                   200                0.086s                0.232s   2021-11-23 20:27:49
#         298                   200                0.080s                0.310s   2021-11-23 20:27:49
#         299                   200                0.037s                0.282s   2021-11-23 20:27:50
#         300                   200                0.044s                0.404s   2021-11-23 20:27:50
#         301                   200                0.053s                0.163s   2021-11-23 20:27:50
#         302                   200                0.056s                0.246s   2021-11-23 20:27:51
#         303                   200                0.019s                0.293s   2021-11-23 20:27:51
#         304                   200                0.030s                0.251s   2021-11-23 20:27:51
#         305                   200                0.036s                0.303s   2021-11-23 20:27:52
#         306                   200                0.005s                0.238s   2021-11-23 20:27:52
#         307                   200                0.052s                0.208s   2021-11-23 20:27:52
#         308                   200                0.044s                0.320s   2021-11-23 20:27:53
#         309                   200                0.023s                0.314s   2021-11-23 20:27:53
#         310                   200                0.020s                0.325s   2021-11-23 20:27:53
#         311                   200                0.094s                0.219s   2021-11-23 20:27:54
#         312                   200                0.053s                0.241s   2021-11-23 20:27:54
#         313                   200                0.043s                0.249s   2021-11-23 20:27:54
#         314                   200                0.028s                0.168s   2021-11-23 20:27:54
#         315                   200                0.026s                0.240s   2021-11-23 20:27:55
#         316                   200                0.090s                0.268s   2021-11-23 20:27:55
#         317                   200                0.072s                0.349s   2021-11-23 20:27:55
#         318                   200                0.098s                0.289s   2021-11-23 20:27:56
#         319                   200                0.070s                0.294s   2021-11-23 20:27:56
#         320                   200                0.043s                0.294s   2021-11-23 20:27:57
#         321                   200                0.006s                0.234s   2021-11-23 20:27:57
#         322                   200                0.002s                0.244s   2021-11-23 20:27:57
#         323                   200                0.096s                0.286s   2021-11-23 20:27:57
#         324                   200                0.071s                0.324s   2021-11-23 20:27:58
#         325                   200                0.057s                0.183s   2021-11-23 20:27:58
#         326                   200                0.023s                0.290s   2021-11-23 20:27:58
#         327                   200                0.004s                0.277s   2021-11-23 20:27:59
#         328                   200                0.042s                0.291s   2021-11-23 20:27:59
#         329                   200                0.029s                0.265s   2021-11-23 20:27:59
#         330                   200                0.098s                0.284s   2021-11-23 20:28:00
#         331                   200                0.049s                0.269s   2021-11-23 20:28:00
#         332                   200                0.049s                0.256s   2021-11-23 20:28:00
#         333                   200                0.082s                0.244s   2021-11-23 20:28:01
#         334                   200                0.008s                0.262s   2021-11-23 20:28:01
#         335                   200                0.062s                0.219s   2021-11-23 20:28:01
#         336                   200                0.017s                0.319s   2021-11-23 20:28:01
#         337                   200                0.056s                0.268s   2021-11-23 20:28:02
#         338                   200                0.026s                0.285s   2021-11-23 20:28:02
#         339                   200                0.054s                0.219s   2021-11-23 20:28:02
#         340                   200                0.008s                0.257s   2021-11-23 20:28:03
#         341                   200                0.032s                0.265s   2021-11-23 20:28:03
#         342                   200                0.091s                0.366s   2021-11-23 20:28:03
#         343                   200                0.092s                0.159s   2021-11-23 20:28:04
#         344                   200                0.022s                0.247s   2021-11-23 20:28:04
#         345                   200                0.076s                0.204s   2021-11-23 20:28:04
#         346                   200                0.097s                0.282s   2021-11-23 20:28:05
#         347                   200                0.025s                0.219s   2021-11-23 20:28:05
#         348                   200                0.033s                0.273s   2021-11-23 20:28:05
#         349                   200                0.026s                0.159s   2021-11-23 20:28:05
#         350                   200                0.049s                0.229s   2021-11-23 20:28:06
#         351                   200                0.003s                0.299s   2021-11-23 20:28:06
#         352                   200                0.046s                0.345s   2021-11-23 20:28:06
#         353                   200                0.022s                0.333s   2021-11-23 20:28:07
#         354                   200                0.034s                0.291s   2021-11-23 20:28:07
#         355                   200                0.038s                0.280s   2021-11-23 20:28:07
#         356                   200                0.063s                0.270s   2021-11-23 20:28:08
#         357                   200                0.082s                0.220s   2021-11-23 20:28:08
#         358                   200                0.087s                0.166s   2021-11-23 20:28:08
#         359                   200                0.067s                0.256s   2021-11-23 20:28:08
#         360                   200                0.095s                0.247s   2021-11-23 20:28:09
#         361                   200                0.020s                0.252s   2021-11-23 20:28:09
#         362                   200                0.066s                0.228s   2021-11-23 20:28:09
#         363                   200                0.025s                0.257s   2021-11-23 20:28:10
#         364                   200                0.037s                0.259s   2021-11-23 20:28:10
#         365                   200                0.088s                0.263s   2021-11-23 20:28:10
#         366                   200                0.077s                0.268s   2021-11-23 20:28:11
#         367                   200                0.097s                0.246s   2021-11-23 20:28:11
#         368                   200                0.058s                0.226s   2021-11-23 20:28:11
#         369                   200                0.071s                0.144s   2021-11-23 20:28:12
#         370                   200                0.062s                0.268s   2021-11-23 20:28:12
#         371                   200                0.025s                0.329s   2021-11-23 20:28:12
#         372                   200                0.051s                0.220s   2021-11-23 20:28:12
#         373                   200                0.003s                0.135s   2021-11-23 20:28:13
#         374                   200                0.096s                0.295s   2021-11-23 20:28:13
#         375                   200                0.087s                0.257s   2021-11-23 20:28:13
#         376                   200                0.053s                0.231s   2021-11-23 20:28:14
#         377                   200                0.016s                0.269s   2021-11-23 20:28:14
#         378                   200                0.074s                0.241s   2021-11-23 20:28:14
#         379                   200                0.033s                0.283s   2021-11-23 20:28:15
#         380                   200                0.074s                0.289s   2021-11-23 20:28:15
#         381                   200                0.033s                0.284s   2021-11-23 20:28:15
#         382                   200                0.066s                0.272s   2021-11-23 20:28:16
#         383                   200                0.064s                0.220s   2021-11-23 20:28:16
#         384                   200                0.081s                0.129s   2021-11-23 20:28:16
#         385                   200                0.080s                0.241s   2021-11-23 20:28:16
#         386                   200                0.017s                0.311s   2021-11-23 20:28:17
#         387                   200                0.027s                0.299s   2021-11-23 20:28:17
#         388                   200                0.060s                0.198s   2021-11-23 20:28:17
#         389                   200                0.013s                0.242s   2021-11-23 20:28:18
#         390                   200                0.004s                0.282s   2021-11-23 20:28:18
#         391                   200                0.031s                0.313s   2021-11-23 20:28:18
#         392                   200                0.096s                0.284s   2021-11-23 20:28:19
#         393                   200                0.086s                0.204s   2021-11-23 20:28:19
#         394                   200                0.055s                0.251s   2021-11-23 20:28:19
#         395                   200                0.075s                0.279s   2021-11-23 20:28:20
#         396                   200                0.035s                0.360s   2021-11-23 20:28:20
#         397                   200                0.013s                0.214s   2021-11-23 20:28:20
#         398                   200                0.001s                0.221s   2021-11-23 20:28:20
#         399                   200                0.044s                0.266s   2021-11-23 20:28:21
#         400                   200                0.009s                0.200s   2021-11-23 20:28:21
#         401                   200                0.100s                0.209s   2021-11-23 20:28:21
#         402                   200                0.088s                0.287s   2021-11-23 20:28:22
#         403                   200                0.047s                0.279s   2021-11-23 20:28:22
#         404                   200                0.095s                0.232s   2021-11-23 20:28:22
#         405                   200                0.047s                0.283s   2021-11-23 20:28:23
#         406                   200                0.057s                0.158s   2021-11-23 20:28:23
#         407                   200                0.003s                0.258s   2021-11-23 20:28:23
#         408                   200                0.038s                0.208s   2021-11-23 20:28:23
#         409                   200                0.081s                0.264s   2021-11-23 20:28:24
#         410                   200                0.070s                0.437s   2021-11-23 20:28:24
#         411                   200                0.024s                0.117s   2021-11-23 20:28:24
#         412                   200                0.005s                0.273s   2021-11-23 20:28:25
#         413                   200                0.061s                0.174s   2021-11-23 20:28:25
#         414                   200                0.075s                0.173s   2021-11-23 20:28:25
#         415                   200                0.026s                0.246s   2021-11-23 20:28:25
#         416                   200                0.035s                0.249s   2021-11-23 20:28:26
#         417                   200                0.080s                0.192s   2021-11-23 20:28:26
#         418                   200                0.049s                0.159s   2021-11-23 20:28:26
#         419                   200                0.074s                0.319s   2021-11-23 20:28:26
#         420                   200                0.021s                0.211s   2021-11-23 20:28:27
#         421                   200                0.099s                0.199s   2021-11-23 20:28:27
#         422                   200                0.042s                0.199s   2021-11-23 20:28:27
#         423                   200                0.089s                0.232s   2021-11-23 20:28:28
#         424                   200                0.083s                0.229s   2021-11-23 20:28:28
#         425                   200                0.075s                0.258s   2021-11-23 20:28:28
#         426                   200                0.032s                0.169s   2021-11-23 20:28:28
#         427                   200                0.052s                0.220s   2021-11-23 20:28:29
#         428                   200                0.002s                0.178s   2021-11-23 20:28:29
#         429                   200                0.068s                0.253s   2021-11-23 20:28:29
#         430                   200                0.090s                0.164s   2021-11-23 20:28:29
#         431                   200                0.081s                0.289s   2021-11-23 20:28:30
#         432                   200                0.046s                0.244s   2021-11-23 20:28:30
#         433                   200                0.078s                0.220s   2021-11-23 20:28:30
#         434                   200                0.078s                0.242s   2021-11-23 20:28:31
#         435                   200                0.098s                0.234s   2021-11-23 20:28:31
#         436                   200                0.030s                0.216s   2021-11-23 20:28:31
#         437                   200                0.005s                0.275s   2021-11-23 20:28:32
#         438                   200                0.045s                0.280s   2021-11-23 20:28:32
#         439                   200                0.045s                0.310s   2021-11-23 20:28:32
#         440                   200                0.056s                0.242s   2021-11-23 20:28:33
#         441                   200                0.023s                0.265s   2021-11-23 20:28:33
#         442                   200                0.010s                0.281s   2021-11-23 20:28:33
#         443                   200                0.012s                0.253s   2021-11-23 20:28:33
#         444                   200                0.004s                0.195s   2021-11-23 20:28:34
# ...
#         343                   200                0.029s                0.335s   2021-11-23 20:28:06
#         344                   200                0.066s                0.221s   2021-11-23 20:28:06
#         345                   200                0.077s                0.252s   2021-11-23 20:28:07
#         346                   200                0.062s                0.265s   2021-11-23 20:28:07
#         347                   200                0.097s                0.259s   2021-11-23 20:28:07
#         348                   200                0.008s                0.257s   2021-11-23 20:28:08
#         349                   200                0.022s                0.235s   2021-11-23 20:28:08
#         350                   200                0.046s                0.174s   2021-11-23 20:28:08
#         351                   200                0.015s                0.214s   2021-11-23 20:28:08
#         352                   200                0.064s                0.163s   2021-11-23 20:28:09
#         353                   200                0.096s                0.213s   2021-11-23 20:28:09
#         354                   200                0.007s                0.306s   2021-11-23 20:28:09
#         355                   200                0.008s                0.283s   2021-11-23 20:28:10
#         356                   200                0.022s                0.269s   2021-11-23 20:28:10
#         357                   200                0.057s                0.200s   2021-11-23 20:28:10
#         358                   200                0.085s                0.242s   2021-11-23 20:28:10
#         359                   200                0.041s                0.301s   2021-11-23 20:28:11
#         360                   200                0.083s                0.265s   2021-11-23 20:28:11
#         361                   200                0.045s                0.281s   2021-11-23 20:28:11
#         362                   200                0.100s                0.297s   2021-11-23 20:28:12
#         363                   200                0.097s                0.339s   2021-11-23 20:28:12
#         364                   200                0.063s                0.284s   2021-11-23 20:28:13
#         365                   200                0.060s                0.295s   2021-11-23 20:28:13
#         366                   200                0.072s                0.216s   2021-11-23 20:28:13
#         367                   200                0.084s                0.197s   2021-11-23 20:28:13
#         368                   200                0.033s                0.201s   2021-11-23 20:28:14
#         369                   200                0.063s                0.256s   2021-11-23 20:28:14
#         370                   200                0.081s                0.185s   2021-11-23 20:28:14
#         371                   200                0.098s                0.259s   2021-11-23 20:28:15
#         372                   200                0.055s                0.207s   2021-11-23 20:28:15
#         373                   200                0.031s                0.262s   2021-11-23 20:28:15
#         374                   200                0.048s                0.313s   2021-11-23 20:28:16
#         375                   200                0.096s                0.294s   2021-11-23 20:28:16
#         376                   200                0.098s                0.272s   2021-11-23 20:28:16
#         377                   200                0.005s                0.295s   2021-11-23 20:28:17
#         378                   200                0.037s                0.230s   2021-11-23 20:28:17
#         379                   200                0.030s                0.216s   2021-11-23 20:28:17
#         380                   200                0.064s                0.275s   2021-11-23 20:28:18
#         381                   200                0.081s                0.254s   2021-11-23 20:28:18
#         382                   200                0.074s                0.340s   2021-11-23 20:28:18
#         383                   200                0.004s                0.243s   2021-11-23 20:28:19
#         384                   200                0.012s                0.206s   2021-11-23 20:28:19
#         385                   200                0.035s                0.195s   2021-11-23 20:28:19
#         386                   200                0.057s                0.197s   2021-11-23 20:28:19
#         387                   200                0.033s                0.260s   2021-11-23 20:28:20
#         388                   200                0.001s                0.293s   2021-11-23 20:28:20
#         389                   200                0.018s                0.229s   2021-11-23 20:28:20
#         390                   200                0.070s                0.247s   2021-11-23 20:28:20
#         391                   200                0.094s                0.285s   2021-11-23 20:28:21
#         392                   200                0.077s                0.242s   2021-11-23 20:28:21
#         393                   200                0.036s                0.133s   2021-11-23 20:28:21
#         394                   200                0.003s                0.254s   2021-11-23 20:28:22
#         395                   200                0.012s                0.289s   2021-11-23 20:28:22
#         396                   200                0.092s                0.226s   2021-11-23 20:28:22
#         397                   200                0.023s                0.166s   2021-11-23 20:28:22
#         398                   200                0.029s                0.270s   2021-11-23 20:28:23
#         399                   200                0.011s                0.284s   2021-11-23 20:28:23
#         400                   200                0.099s                0.294s   2021-11-23 20:28:23
#         401                   200                0.030s                0.251s   2021-11-23 20:28:24
#         402                   200                0.028s                0.253s   2021-11-23 20:28:24
#         403                   200                0.071s                0.335s   2021-11-23 20:28:24
#         404                   200                0.093s                0.277s   2021-11-23 20:28:25
#         405                   200                0.077s                0.280s   2021-11-23 20:28:25
#         406                   200                0.089s                0.281s   2021-11-23 20:28:25
#         407                   200                0.027s                0.291s   2021-11-23 20:28:26
#         408                   200                0.072s                0.237s   2021-11-23 20:28:26
#         409                   200                0.038s                0.227s   2021-11-23 20:28:26
#         410                   200                0.030s                0.240s   2021-11-23 20:28:27
#         411                   200                0.062s                0.264s   2021-11-23 20:28:27
#         412                   200                0.080s                0.154s   2021-11-23 20:28:27
#         413                   200                0.018s                0.163s   2021-11-23 20:28:27
#         414                   200                0.003s                0.262s   2021-11-23 20:28:28
#         415                   200                0.043s                0.217s   2021-11-23 20:28:28
#         416                   200                0.078s                0.217s   2021-11-23 20:28:28
#         417                   200                0.084s                0.248s   2021-11-23 20:28:28
#         418                   200                0.059s                0.234s   2021-11-23 20:28:29
#         419                   200                0.082s                0.202s   2021-11-23 20:28:29
#         420                   200                0.068s                0.222s   2021-11-23 20:28:29
#         421                   200                0.021s                0.091s   2021-11-23 20:28:29
#         422                   200                0.028s                0.274s   2021-11-23 20:28:30
#         423                   200                0.070s                0.286s   2021-11-23 20:28:30
#         424                   200                0.097s                0.229s   2021-11-23 20:28:30
#         425                   200                0.081s                0.257s   2021-11-23 20:28:31
#         426                   200                0.076s                0.215s   2021-11-23 20:28:31
#         427                   200                0.032s                0.216s   2021-11-23 20:28:31
#         428                   200                0.097s                0.189s   2021-11-23 20:28:32
#         429                   200                0.069s                0.253s   2021-11-23 20:28:32
#         430                   200                0.060s                0.235s   2021-11-23 20:28:32
#         431                   200                0.065s                0.305s   2021-11-23 20:28:33
#         432                   200                0.065s                0.270s   2021-11-23 20:28:33
#         433                   200                0.031s                0.251s   2021-11-23 20:28:33
#         434                   200                0.018s                0.271s   2021-11-23 20:28:34
#         435                   200                0.013s                0.252s   2021-11-23 20:28:34
#         436                   200                0.069s                0.205s   2021-11-23 20:28:34
#         437                   200                0.088s                0.230s   2021-11-23 20:28:34
#         438                   200                0.063s                0.224s   2021-11-23 20:28:35
#         439                   200                0.001s                0.320s   2021-11-23 20:28:35
#         440                   200                0.003s                0.200s   2021-11-23 20:28:35
#         441                   200                0.092s                0.229s   2021-11-23 20:28:35
#         442                   200                0.091s                0.195s   2021-11-23 20:28:36
#         443                   200                0.081s                0.193s   2021-11-23 20:28:36
#         444                   200                0.051s                0.208s   2021-11-23 20:28:36
#         445                   200                0.055s                0.255s   2021-11-23 20:28:37
#         446                   200                0.005s                0.257s   2021-11-23 20:28:37
#         447                   200                0.051s                0.243s   2021-11-23 20:28:37
#         448                   200                0.088s                0.219s   2021-11-23 20:28:37
#         449                   200                0.047s                0.120s   2021-11-23 20:28:38
#         450                   200                0.010s                0.255s   2021-11-23 20:28:38
#         451                   200                0.049s                0.270s   2021-11-23 20:28:38
#         452                   200                0.040s                0.351s   2021-11-23 20:28:39
#         453                   200                0.084s                0.239s   2021-11-23 20:28:39
#         454                   200                0.079s                0.187s   2021-11-23 20:28:39
#         455                   200                0.037s                0.241s   2021-11-23 20:28:39
#         456                   200                0.007s                0.395s   2021-11-23 20:28:40
#         457                   200                0.057s                0.196s   2021-11-23 20:28:40
#         458                   200                0.097s                0.193s   2021-11-23 20:28:40
#         459                   200                0.017s                0.227s   2021-11-23 20:28:41
#         460                   200                0.069s                0.243s   2021-11-23 20:28:41
#         461                   200                0.015s                0.245s   2021-11-23 20:28:41
#         462                   200                0.066s                0.191s   2021-11-23 20:28:41
#         463                   200                0.074s                0.152s   2021-11-23 20:28:42
#         464                   200                0.026s                0.181s   2021-11-23 20:28:42
#         465                   200                0.097s                0.230s   2021-11-23 20:28:42
#         466                   200                0.073s                0.262s   2021-11-23 20:28:43
#         467                   200                0.042s                0.205s   2021-11-23 20:28:43
#         468                   200                0.074s                0.292s   2021-11-23 20:28:43
#         469                   200                0.060s                0.222s   2021-11-23 20:28:43
#         470                   200                0.085s                0.207s   2021-11-23 20:28:44
#         471                   200                0.076s                0.147s   2021-11-23 20:28:44
#         472                   200                0.068s                0.205s   2021-11-23 20:28:44
#         473                   200                0.080s                0.292s   2021-11-23 20:28:45
#         474                   200                0.020s                0.230s   2021-11-23 20:28:45
#         475                   200                0.074s                0.220s   2021-11-23 20:28:45
#         476                   200                0.090s                0.230s   2021-11-23 20:28:45
#         477                   200                0.036s                0.240s   2021-11-23 20:28:46
#         478                   200                0.081s                0.212s   2021-11-23 20:28:46
#         479                   200                0.053s                0.224s   2021-11-23 20:28:46
#         480                   200                0.096s                0.306s   2021-11-23 20:28:47
#         481                   200                0.036s                0.173s   2021-11-23 20:28:47
#         482                   200                0.042s                0.338s   2021-11-23 20:28:47
#         483                   200                0.026s                0.236s   2021-11-23 20:28:48
#         484                   200                0.086s                0.280s   2021-11-23 20:28:48
#         485                   200                0.083s                0.219s   2021-11-23 20:28:48
#         486                   200                0.002s                0.233s   2021-11-23 20:28:49
#         487                   200                0.014s                0.291s   2021-11-23 20:28:49
#         488                   200                0.080s                0.277s   2021-11-23 20:28:49
#         489                   200                0.020s                0.268s   2021-11-23 20:28:50
#         490                   200                0.040s                0.217s   2021-11-23 20:28:50
#         491                   200                0.100s                0.258s   2021-11-23 20:28:50
#         492                   200                0.067s                0.232s   2021-11-23 20:28:50
#         493                   200                0.014s                0.264s   2021-11-23 20:28:51
#         494                   200                0.010s                0.172s   2021-11-23 20:28:51
#         495                   200                0.098s                0.145s   2021-11-23 20:28:51
#         496                   200                0.045s                0.103s   2021-11-23 20:28:51
#         497                   200                0.086s                0.108s   2021-11-23 20:28:51
#         498                   200                0.037s                0.108s   2021-11-23 20:28:52
#         499                   200                0.024s                0.109s   2021-11-23 20:28:52
#         500                   200                0.038s                0.104s   2021-11-23 20:28:52
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-1 : All tests passed!
# All threads passed stress_test function.
